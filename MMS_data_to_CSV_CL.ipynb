# %%
# make sounds when long code is done running!
from IPython.display import Audio
sound_file = '/Users/chle4971/Music/your_code_is_done_running.mp3'



import os
cwd = os.getcwd()

print(cwd)
# Out:
# /Users/chle4971/Library/Mobile Documents/com~apple~CloudDocs/LASP-MacL4326/MMS/MMS_code/MMS_Python

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#pd.options.plotting.backend = "plotly"

#import logging
# from pyspedas.cotrans.cotrans_get_coord import cotrans_get_coord
# from pyspedas.cotrans.cotrans import cotrans
# from pyspedas.cotrans.gsm2lmn import gsm2lmn
from pyspedas.mms import mec
#from pyspedas import tinterpol, omni
import os
import pyspedas
from pytplot import tplot, get_data, store_data, tlimit, options,tplot_names
from pyspedas.mms import fpi,fgm
#from pyspedas.mms.mms_orbit_plot import mms_orbit_plot

# logging.captureWarnings(True)
# logging.basicConfig(format='%(asctime)s: %(message)s', datefmt='%d-%b-%y %H:%M:%S', level=logging.INFO)

# %% [markdown]
# ### save FGM and FPI vars in GSM coordinates

# %%
# # save FGM vars in GSM coordinate system


# use_spedas ='yes'
# create_csv ='yes'



# if use_spedas == 'yes':
    
#     trange = ['2020-06-17/20:00:00','2020-06-18/01:30:00']
    
#     # OMNI data:
#     # omni_vars = pyspedas.omni.data(trange=trange)
    
#     # MMS data:
#     probe = ['2']

#     #electron_vars = fpi(probe=probe,datatype='des-moms', trange=trange, data_rate='brst',center_measurement=True)
#     # Load all of the FPI data
#     ion_vars = fpi(probe = probe,data_rate = 'brst',datatype = 'dis-moms',
#                    trange = trange, center_measurement = True)
    
#     fgm_vars = fgm(trange = trange, probe = probe, data_rate = 'brst')

  
    
#     # 2024-04-27 this doesn't change anything about the velocity, maybe because there isn't a different between
#     # mms2_dis_bulkv_gse_brst and mms2_dis_bulkv_gsm_brst
#     from pyspedas import cotrans
#     cotrans(name_in='mms2_dis_bulkv_gse_brst', name_out='mms2_dis_bulkv_gsm_brst', coord_in='gse', coord_out='gsm')
    
#     b_field_mms2 = 'mms2_fgm_b_gsm_brst_l2'
#     times_b_mms2, data_b_mms2 = get_data(b_field_mms2)
    
#     V_mms2 = 'mms2_dis_bulkv_gsm_brst'
#     times_v_mms2, data_v_mms2 = get_data(V_mms2)

    
    
#     # MMS2 data for time period
    
#     MMS2_B_gsm = pd.DataFrame({"times": times_b_mms2, "Bx": data_b_mms2[:,0],
#                            "By": data_b_mms2[:,1], "Bz": data_b_mms2[:,2],"Bmag": data_b_mms2[:,3]})

   
#     MMS2_V_gsm = pd.DataFrame({"times": times_v_mms2, "Vx": data_v_mms2[:,0],
#                            "Vy": data_v_mms2[:,1], "Vz": data_v_mms2[:,2]})
    
    
 

    
#     MMS2_B_gsm['date'] = pd.to_datetime(MMS2_B_gsm['times'],unit='s')
   
#     MMS2_V_gsm['date'] = pd.to_datetime(MMS2_V_gsm['times'],unit='s')
    
   


 
#     if create_csv == 'yes':
#         MMS2_B_gsm.to_csv('MMS2_B_gsm.csv', index=False)  
#         MMS2_V_gsm.to_csv('MMS2_V_gsm.csv', index=False)  
       

#         # plot data
#     import pytplot
#     #pytplot.tplot_options('title','Raw data')
#     options('mms2_fgm_b_gsm_brst_l2','ytitle','Magnetic Field')
#     options('mms2_fgm_b_gsm_brst_l2','ysubtitle','[nT]')
#     options('mms2_dis_bulkv_gsm_brst','ytitle','V')
#     options('mms2_dis_bulkv_gsm_brst','ysubtitle','[km/s]')


#     #tlimit(['2020-06-17/20:30:00','2020-06-18/01:30:00'])
    
    
#     # OMNI data
#    # tplot(['BX_gsm', 'BY_gsm', 'BZ_gsm', 'flow_speed', 'Vx', 'Vy', 'Vz', 'SYM_H'])

# %% [markdown]
# ### Generate .csv from FGM,FPI in GSE coordinates

# %%
#load GSE data for ALL MMS



use_spedas ='yes'
create_csv ='yes'



if use_spedas == 'yes':
    
    trange = ['2020-06-17/20:30:00','2020-06-18/01:30:00']
    
    # OMNI data:
    # omni_vars = pyspedas.omni.data(trange=trange)
    
    # MMS data:
    #probe = ['1','2','3','4']
    probe = ['2']

   # electroni_vars = fpi(probe=probe,datatype='des-moms', trange=trange, data_rate='brst',center_measurement=True)
    # Load all of the FPI data
    ion_vars = fpi(probe = probe,data_rate = 'brst',datatype = 'dis-moms',
                   trange = trange, center_measurement = True)
    
    fgm_vars = fgm(trange = trange, probe = probe, data_rate = 'brst')

    
    # b_field_MMS1 = 'mms1_fgm_b_gse_brst_l2'

    # times_b_MMS1, data_b_MMS1 = get_data(b_field_MMS1)
    
    
    # ni_MMS1 = 'mms1_dis_numberdensity_brst'
    # times_ni_MMS1, data_ni_MMS1 = get_data(ni_MMS1)

    # Tipara_MMS1 = 'mms1_dis_temppara_brst'
    # times_Tipara_MMS1, data_Tipara_MMS1 = get_data(Tipara_MMS1)

    # Tiperp_MMS1 = 'mms1_dis_tempperp_brst'
    # times_Tiperp_MMS1, data_Tiperp_MMS1 = get_data(Tiperp_MMS1)

    # Vi_MMS1 = 'mms1_dis_bulkv_gse_brst'
    # times_vi_MMS1, data_vi_MMS1 = get_data(Vi_MMS1)
    
    
    # MMS1_B = pd.DataFrame({"times": times_b_MMS1, "Bx": data_b_MMS1[:,0],
    #                        "By": data_b_MMS1[:,1], "Bz": data_b_MMS1[:,2],"Bmag": data_b_MMS1[:,3]})

    # MMS1_ni = pd.DataFrame({"times": times_ni_MMS1, "ni": data_ni_MMS1})

    # MMS1_Tipara = pd.DataFrame({"times": times_Tipara_MMS1, "Tipara": data_Tipara_MMS1})

    # MMS1_Tiperp = pd.DataFrame({"times": times_Tiperp_MMS1, "Tiperp": data_Tiperp_MMS1})

    # MMS1_Vi = pd.DataFrame({"times": times_vi_MMS1, "Vix": data_vi_MMS1[:,0],
    #                        "Viy": data_vi_MMS1[:,1], "Viz": data_vi_MMS1[:,2]})
    
    
    b_field_mms2 = 'mms2_fgm_b_gse_brst_l2'
    times_b_mms2, data_b_mms2 = get_data(b_field_mms2)
    
    
    ni_mms2 = 'mms2_dis_numberdensity_brst'
    times_ni_mms2, data_ni_mms2 = get_data(ni_mms2)

    Tipara_mms2 = 'mms2_dis_temppara_brst'
    times_Tipara_mms2, data_Tipara_mms2 = get_data(Tipara_mms2)

    Tiperp_mms2 = 'mms2_dis_tempperp_brst'
    times_Tiperp_mms2, data_Tiperp_mms2 = get_data(Tiperp_mms2)

    Vi_mms2 = 'mms2_dis_bulkv_gse_brst'
    times_vi_mms2, data_vi_mms2 = get_data(Vi_mms2)

    
    
    # MMS2 data for time period
    
    MMS2_B = pd.DataFrame({"times": times_b_mms2, "Bx": data_b_mms2[:,0],
                           "By": data_b_mms2[:,1], "Bz": data_b_mms2[:,2],"Bmag": data_b_mms2[:,3]})

    MMS2_ni = pd.DataFrame({"times": times_ni_mms2, "ni": data_ni_mms2})

    MMS2_Tipara = pd.DataFrame({"times": times_Tipara_mms2, "Tipara": data_Tipara_mms2})

    MMS2_Tiperp = pd.DataFrame({"times": times_Tiperp_mms2, "Tiperp": data_Tiperp_mms2})

    MMS2_Vi = pd.DataFrame({"times": times_vi_mms2, "Vix": data_vi_mms2[:,0],
                           "Viy": data_vi_mms2[:,1], "Viz": data_vi_mms2[:,2]})
    
    
    
    # b_field_mms3 = 'mms3_fgm_b_gse_brst_l2'
    # times_b_mms3, data_b_mms3 = get_data(b_field_mms3)
    

    # ni_mms3 = 'mms3_dis_numberdensity_brst'
    # times_ni_mms3, data_ni_mms3 = get_data(ni_mms3)

    # Tipara_mms3 = 'mms3_dis_temppara_brst'
    # times_Tipara_mms3, data_Tipara_mms3 = get_data(Tipara_mms3)

    # Tiperp_mms3 = 'mms3_dis_tempperp_brst'
    # times_Tiperp_mms3, data_Tiperp_mms3 = get_data(Tiperp_mms3)

    # Vi_mms3 = 'mms3_dis_bulkv_gse_brst'
    # times_vi_mms3, data_vi_mms3 = get_data(Vi_mms3)

    
    
    # # mms3 data for time period
    
    # MMS3_B = pd.DataFrame({"times": times_b_mms3, "Bx": data_b_mms3[:,0],
    #                        "By": data_b_mms3[:,1], "Bz": data_b_mms3[:,2],"Bmag": data_b_mms3[:,3]})

    # MMS3_ni = pd.DataFrame({"times": times_ni_mms3, "ni": data_ni_mms3})

    # MMS3_Tipara = pd.DataFrame({"times": times_Tipara_mms3, "Tipara": data_Tipara_mms3})

    # MMS3_Tiperp = pd.DataFrame({"times": times_Tiperp_mms3, "Tiperp": data_Tiperp_mms3})

    # MMS3_Vi = pd.DataFrame({"times": times_vi_mms3, "Vix": data_vi_mms3[:,0],
    #                        "Viy": data_vi_mms3[:,1], "Viz": data_vi_mms3[:,2]})
    
    
    
    
    # b_field_mms4 = 'mms4_fgm_b_gse_brst_l2'
    # times_b_mms4, data_b_mms4 = get_data(b_field_mms4)
    

    # ni_mms4 = 'mms4_dis_numberdensity_brst'
    # times_ni_mms4, data_ni_mms4 = get_data(ni_mms4)

    # Tipara_mms4 = 'mms4_dis_temppara_brst'
    # times_Tipara_mms4, data_Tipara_mms4 = get_data(Tipara_mms4)

    # Tiperp_mms4 = 'mms4_dis_tempperp_brst'
    # times_Tiperp_mms4, data_Tiperp_mms4 = get_data(Tiperp_mms4)

    # Vi_mms4 = 'mms4_dis_bulkv_gse_brst'
    # times_vi_mms4, data_vi_mms4 = get_data(Vi_mms4)

    
    
    # # mms4 data for time period
    
    # MMS4_B = pd.DataFrame({"times": times_b_mms4, "Bx": data_b_mms4[:,0],
    #                        "By": data_b_mms4[:,1], "Bz": data_b_mms4[:,2],"Bmag": data_b_mms4[:,3]})

    # MMS4_ni = pd.DataFrame({"times": times_ni_mms4, "ni": data_ni_mms4})

    # MMS4_Tipara = pd.DataFrame({"times": times_Tipara_mms4, "Tipara": data_Tipara_mms4})

    # MMS4_Tiperp = pd.DataFrame({"times": times_Tiperp_mms4, "Tiperp": data_Tiperp_mms4})

    # MMS4_Vi = pd.DataFrame({"times": times_vi_mms4, "Vix": data_vi_mms4[:,0],
    #                        "Viy": data_vi_mms4[:,1], "Viz": data_vi_mms4[:,2]})
    
    #OMNI_B_GSE = pd.DataFrame({""})
#     OMNI_Bx_GSE = 'BX_GSE'
#     times_OMNI_Bx, data_OMNI_Bx = get_data(OMNI_Bx_GSE)

#     OMNI_By_GSE = 'BY_GSE'
#     times_OMNI_By, data_OMNI_By = get_data(OMNI_By_GSE)
    
#     OMNI_Bz_GSE = 'BZ_GSE'
#     times_OMNI_Bz, data_OMNI_Bz = get_data(OMNI_Bz_GSE)
    
#     OMNI_Vix_GSE = 'VX_GSE'
#     times_OMNI_Vix, data_OMNI_Vix = get_data(OMNI_Vix_GSE)

#     OMNI_Viy_GSE = 'VY_GSE'
#     times_OMNI_Viy, data_OMNI_Viy = get_data(OMNI_Viy_GSE)
    
#     OMNI_Viz_GSE = 'VZ_GSE'
#     times_OMNI_Viz, data_OMNI_Viz = get_data(OMNI_Viz_GSE)
    
    
#     OMNI_IMF = 'IMF'
#     times_OMNI_IMF, data_OMNI_IMF = get_data(OMNI_IMF)

#     OMNI_flow_speed = 'flow_speed'
#     times_flow_speed, data_flow_speed = get_data(OMNI_flow_speed)    


#     #OMNI_B = pd.DataFrame({"times": times_OMNI_Bx, "Bx": data_OMNI_Bx, "By": data_OMNI_By, "Bz": data_OMNI_Bz})

#     OMNI_IMF = pd.DataFrame({"times":times_OMNI_IMF,"IMF":data_OMNI_IMF})

#     OMNI_flow_speed = pd.DataFrame({"times":times_flow_speed,"flow_speed":data_flow_speed})

#     OMNI_IMF['date'] = pd.to_datetime(OMNI_IMF['times'],unit='s')
#     OMNI_flow_speed['date'] = pd.to_datetime(OMNI_flow_speed['times'],unit='s')

    
    # MMS1_B['date'] = pd.to_datetime(MMS1_B['times'],unit='s')
    # MMS1_ni['date'] = pd.to_datetime(MMS1_ni['times'],unit='s')
    # MMS1_Tipara['date'] = pd.to_datetime(MMS1_Tipara['times'],unit='s')
    # MMS1_Tiperp['date'] = pd.to_datetime(MMS1_Tiperp['times'],unit='s')
    # MMS1_Vi['date'] = pd.to_datetime(MMS1_Vi['times'],unit='s')

    
    MMS2_B['date'] = pd.to_datetime(MMS2_B['times'],unit='s')
    MMS2_ni['date'] = pd.to_datetime(MMS2_ni['times'],unit='s')
    MMS2_Tipara['date'] = pd.to_datetime(MMS2_Tipara['times'],unit='s')
    MMS2_Tiperp['date'] = pd.to_datetime(MMS2_Tiperp['times'],unit='s')
    MMS2_Vi['date'] = pd.to_datetime(MMS2_Vi['times'],unit='s')
    
    
    # MMS3_B['date'] = pd.to_datetime(MMS3_B['times'],unit='s')
    # MMS3_ni['date'] = pd.to_datetime(MMS3_ni['times'],unit='s')
    # MMS3_Tipara['date'] = pd.to_datetime(MMS3_Tipara['times'],unit='s')
    # MMS3_Tiperp['date'] = pd.to_datetime(MMS3_Tiperp['times'],unit='s')
    # MMS3_Vi['date'] = pd.to_datetime(MMS3_Vi['times'],unit='s')
    
    # MMS4_B['date'] = pd.to_datetime(MMS4_B['times'],unit='s')
    # MMS4_ni['date'] = pd.to_datetime(MMS4_ni['times'],unit='s')
    # MMS4_Tipara['date'] = pd.to_datetime(MMS4_Tipara['times'],unit='s')
    # MMS4_Tiperp['date'] = pd.to_datetime(MMS4_Tiperp['times'],unit='s')
    # MMS4_Vi['date'] = pd.to_datetime(MMS4_Vi['times'],unit='s')




 
    if create_csv == 'yes':
        MMS2_B.to_csv('MMS2_B.csv', index=False)  
        MMS2_ni.to_csv('MMS2_ni.csv', index=False)  
        MMS2_Tipara.to_csv('MMS2_Tipara.csv', index=False)  
        MMS2_Tiperp.to_csv('MMS2_Tiperp.csv', index=False)  
        MMS2_Vi.to_csv('MMS2_Vi.csv', index=False)  
        
        # MMS1_B.to_csv('MMS1_B.csv', index=False)  
        # MMS1_ni.to_csv('MMS1_ni.csv', index=False)  
        # MMS1_Tipara.to_csv('MMS1_Tipara.csv', index=False)  
        # MMS1_Tiperp.to_csv('MMS1_Tiperp.csv', index=False)  
        # MMS1_Vi.to_csv('MMS1_Vi.csv', index=False)  
        
        # MMS3_B.to_csv('MMS3_B.csv', index=False)  
        # MMS3_ni.to_csv('MMS3_ni.csv', index=False)  
        # MMS3_Tipara.to_csv('MMS3_Tipara.csv', index=False)  
        # MMS3_Tiperp.to_csv('MMS3_Tiperp.csv', index=False)  
        # MMS3_Vi.to_csv('MMS3_Vi.csv', index=False)  
        
        # MMS4_B.to_csv('MMS4_B.csv', index=False)  
        # MMS4_ni.to_csv('MMS4_ni.csv', index=False)  
        # MMS4_Tipara.to_csv('MMS4_Tipara.csv', index=False)  
        # MMS4_Tiperp.to_csv('MMS4_Tiperp.csv', index=False)  
        # MMS4_Vi.to_csv('MMS4_Vi.csv', index=False)  

        # plot data
   #  import pytplot
   #  #pytplot.tplot_options('title','Raw data')
   #  options('mms2_fgm_b_gse_brst_l2','ytitle','Magnetic Field')
   #  options('mms2_fgm_b_gse_brst_l2','ysubtitle','[nT]')
   #  options('mms2_dis_bulkv_gse_brst','ytitle','V')
   #  options('mms2_dis_bulkv_gse_brst','ysubtitle','[km/s]')

   #  options('mms2_dis_numberdensity_brst','ytitle','n')
   #  options('mms2_dis_numberdensity_brst','ysubtitle','[$cm^{-3}$]')

   #  options('mms2_dis_prestensor_gse_brst','ytitle','P')
   #  options('mms2_dis_prestensor_gse_brst','ysubtitle','[nPa]')

   #  #tlimit(['2020-06-17/20:30:00','2020-06-18/01:30:00'])
    
    
   #  # OMNI data
   # # tplot(['BX_GSE', 'BY_GSE', 'BZ_GSE', 'flow_speed', 'Vix', 'Viy', 'Viz', 'SYM_H'])


   #  ne_MMS1 = 'mms1_des_numberdensity_brst'
   #  times_ne_MMS1, data_ne_MMS1 = get_data(ne_MMS1)

   #  Tepara_MMS1 = 'mms1_des_temppara_brst'
   #  times_Tepara_MMS1, data_Tepara_MMS1 = get_data(Tepara_MMS1)

   #  Teperp_MMS1 = 'mms1_des_tempperp_brst'
   #  times_Teperp_MMS1, data_Teperp_MMS1 = get_data(Teperp_MMS1)

   #  Ve_MMS1 = 'mms1_des_bulkv_gse_brst'
   #  times_ve_MMS1, data_ve_MMS1 = get_data(Ve_MMS1)
    

   #  MMS1_ne = pd.DataFrame({"times": times_ne_MMS1, "ne": data_ne_MMS1})

   #  MMS1_Tepara = pd.DataFrame({"times": times_Tepara_MMS1, "Tepara": data_Tepara_MMS1})

   #  MMS1_Teperp = pd.DataFrame({"times": times_Teperp_MMS1, "Teperp": data_Teperp_MMS1})

   #  MMS1_Ve = pd.DataFrame({"times": times_ve_MMS1, "Vex": data_ve_MMS1[:,0],
   #                         "Vey": data_ve_MMS1[:,1], "Vez": data_ve_MMS1[:,2]})
    
    
    # ne_mms2 = 'mms2_des_numberdensity_brst'
    # times_ne_mms2, data_ne_mms2 = get_data(ne_mms2)

    # Tepara_mms2 = 'mms2_des_temppara_brst'
    # times_Tepara_mms2, data_Tepara_mms2 = get_data(Tepara_mms2)

    # Teperp_mms2 = 'mms2_des_tempperp_brst'
    # times_Teperp_mms2, data_Teperp_mms2 = get_data(Teperp_mms2)

    # Ve_mms2 = 'mms2_des_bulkv_gse_brst'
    # times_ve_mms2, data_ve_mms2 = get_data(Ve_mms2)

    

    # MMS2_ne = pd.DataFrame({"times": times_ne_mms2, "ne": data_ne_mms2})

    # MMS2_Tepara = pd.DataFrame({"times": times_Tepara_mms2, "Tepara": data_Tepara_mms2})

    # MMS2_Teperp = pd.DataFrame({"times": times_Teperp_mms2, "Teperp": data_Teperp_mms2})

    # MMS2_Ve = pd.DataFrame({"times": times_ve_mms2, "Vex": data_ve_mms2[:,0],
    #                        "Vey": data_ve_mms2[:,1], "Vez": data_ve_mms2[:,2]})
    
    
    
    # ne_mms3 = 'mms3_des_numberdensity_brst'
    # times_ne_mms3, data_ne_mms3 = get_data(ne_mms3)

    # Tepara_mms3 = 'mms3_des_temppara_brst'
    # times_Tepara_mms3, data_Tepara_mms3 = get_data(Tepara_mms3)

    # Teperp_mms3 = 'mms3_des_tempperp_brst'
    # times_Teperp_mms3, data_Teperp_mms3 = get_data(Teperp_mms3)

    # Ve_mms3 = 'mms3_des_bulkv_gse_brst'
    # times_ve_mms3, data_ve_mms3 = get_data(Ve_mms3)

    
    
    # mms3_ne = pd.DataFrame({"times": times_ne_mms3, "ne": data_ne_mms3})

    # mms3_Tepara = pd.DataFrame({"times": times_Tepara_mms3, "Tepara": data_Tepara_mms3})

    # mms3_Teperp = pd.DataFrame({"times": times_Teperp_mms3, "Teperp": data_Teperp_mms3})

    # mms3_Ve = pd.DataFrame({"times": times_ve_mms3, "Vex": data_ve_mms3[:,0],
    #                        "Vey": data_ve_mms3[:,1], "Vez": data_ve_mms3[:,2]})
    
    
    
    # ne_mms4 = 'mms4_des_numberdensity_brst'
    # times_ne_mms4, data_ne_mms4 = get_data(ne_mms4)

    # Tepara_mms4 = 'mms4_des_temppara_brst'
    # times_Tepara_mms4, data_Tepara_mms4 = get_data(Tepara_mms4)

    # Teperp_mms4 = 'mms4_des_tempperp_brst'
    # times_Teperp_mms4, data_Teperp_mms4 = get_data(Teperp_mms4)

    # Ve_mms4 = 'mms4_des_bulkv_gse_brst'
    # times_ve_mms4, data_ve_mms4 = get_data(Ve_mms4)

    
    
    # mms4_ne = pd.DataFrame({"times": times_ne_mms4, "ne": data_ne_mms4})

    # mms4_Tepara = pd.DataFrame({"times": times_Tepara_mms4, "Tepara": data_Tepara_mms4})

    # mms4_Teperp = pd.DataFrame({"times": times_Teperp_mms4, "Teperp": data_Teperp_mms4})

    # mms4_Ve = pd.DataFrame({"times": times_ve_mms4, "Vex": data_ve_mms4[:,0],
    #                          "Vey": data_ve_mms4[:,1], "Vez": data_ve_mms4[:,2]})
          
    # MMS1_ne['date'] = pd.to_datetime(MMS1_ne['times'],unit='s')
    # MMS1_Tepara['date'] = pd.to_datetime(MMS1_Tepara['times'],unit='s')
    # MMS1_Teperp['date'] = pd.to_datetime(MMS1_Teperp['times'],unit='s')
    # MMS1_Ve['date'] = pd.to_datetime(MMS1_Ve['times'],unit='s')

    
    # MMS2_ne['date'] = pd.to_datetime(MMS2_ne['times'],unit='s')
    # MMS2_Tepara['date'] = pd.to_datetime(MMS2_Tepara['times'],unit='s')
    # MMS2_Teperp['date'] = pd.to_datetime(MMS2_Teperp['times'],unit='s')
    # MMS2_Ve['date'] = pd.to_datetime(MMS2_Ve['times'],unit='s')
    
    
    # MMS3_ne['date'] = pd.to_datetime(MMS3_ne['times'],unit='s')
    # MMS3_Tepara['date'] = pd.to_datetime(MMS3_Tepara['times'],unit='s')
    # MMS3_Teperp['date'] = pd.to_datetime(MMS3_Teperp['times'],unit='s')
    # MMS3_Ve['date'] = pd.to_datetime(MMS3_Ve['times'],unit='s')
    
    # MMS4_ne['date'] = pd.to_datetime(MMS4_ne['times'],unit='s')
    # MMS4_Tepara['date'] = pd.to_datetime(MMS4_Tepara['times'],unit='s')
    # MMS4_Teperp['date'] = pd.to_datetime(MMS4_Teperp['times'],unit='s')
    # MMS4_Ve['date'] = pd.to_datetime(MMS4_Ve['times'],unit='s')




 
    # if create_csv == 'yes':
    #     MMS2_ne.to_csv('MMS2_ne.csv', index=False)  
    #     MMS2_Tepara.to_csv('MMS2_Tepara.csv', index=False)  
    #     MMS2_Teperp.to_csv('MMS2_Teperp.csv', index=False)  
    #     MMS2_Ve.to_csv('MMS2_Ve.csv', index=False)  
        
    #     MMS1_ne.to_csv('MMS1_ne.csv', index=False)  
    #     MMS1_Tepara.to_csv('MMS1_Tepara.csv', index=False)  
    #     MMS1_Teperp.to_csv('MMS1_Teperp.csv', index=False)  
    #     MMS1_Ve.to_csv('MMS1_Ve.csv', index=False)  
        
    #     MMS3_ne.to_csv('MMS3_ne.csv', index=False)  
    #     MMS3_Tepara.to_csv('MMS3_Tepara.csv', index=False)  
    #     MMS3_Teperp.to_csv('MMS3_Teperp.csv', index=False)  
    #     MMS3_Ve.to_csv('MMS3_Ve.csv', index=False)  
        
    #     MMS4_ne.to_csv('MMS4_ne.csv', index=False)  
    #     MMS4_Tepara.to_csv('MMS4_Tepara.csv', index=False)  
    #     MMS4_Teperp.to_csv('MMS4_Teperp.csv', index=False)  
    #     MMS4_Ve.to_csv('MMS4_Ve.csv', index=False)
# Out:
# 11-Sep-24 12:24:06: Loading pydata/mms2/fpi/brst/l2/dis-moms/2020/06/17/mms2_fpi_brst_l2_dis-moms_20200617202923_v3.4.0.cdf
# 11-Sep-24 12:24:06: Loading pydata/mms2/fpi/brst/l2/dis-moms/2020/06/17/mms2_fpi_brst_l2_dis-moms_20200617203153_v3.4.0.cdf
# 11-Sep-24 12:24:06: Loading pydata/mms2/fpi/brst/l2/dis-moms/2020/06/17/mms2_fpi_brst_l2_dis-moms_20200617203423_v3.4.0.cdf
# 11-Sep-24 12:24:06: Loading pydata/mms2/fpi/brst/l2/dis-moms/2020/06/17/mms2_fpi_brst_l2_dis-moms_20200617203653_v3.4.0.cdf
# 11-Sep-24 12:24:06: Loading pydata/mms2/fpi/brst/l2/dis-moms/2020/06/17/mms2_fpi_brst_l2_dis-moms_20200617203923_v3.4.0.cdf
# 11-Sep-24 12:24:06: Loading pydata/mms2/fpi/brst/l2/dis-moms/2020/06/17/mms2_fpi_brst_l2_dis-moms_20200617204153_v3.4.0.cdf
# 11-Sep-24 12:24:06: Loading pydata/mms2/fpi/brst/l2/dis-moms/2020/06/17/mms2_fpi_brst_l2_dis-moms_20200617204413_v3.4.0.cdf
# ...

# %%
# ion_vars = fpi(probe = 1,data_rate = 'brst',datatype = 'dis-moms',
#                    trange = trange, center_measurement = True)

# P_mms1 = 'mms1_dis_prestensor_gse_brst'
# times_p_mms1, data_p_mms1 = get_data(P_mms1)

# n_mms1 = 'mms1_dis_numberdensity_brst'
# times_n_mms1, data_n_mms1 = get_data(n_mms1)

# Tpara_mms1 = 'mms1_dis_temppara_brst'
# times_Tpara_mms1, data_Tpara_mms1 = get_data(Tpara_mms1)

# Tperp_mms1 = 'mms1_dis_tempperp_brst'
# times_Tperp_mms1, data_Tperp_mms1 = get_data(Tperp_mms1)

# V_mms1 = 'mms1_dis_bulkv_gse_brst'
# times_v_mms1, data_v_mms1 = get_data(V_mms1)





# # mms1 data for time period

# # mms1_B = pd.DataFrame({"times": times_b_mms1, "Bx": data_b_mms1[:,0],
# #                    "By": data_b_mms1[:,1], "Bz": data_b_mms1[:,2],"Bmag": data_b_mms1[:,1]})
# #mms1_P = pd.DataFrame({"times": times1, "Px": data1[:,0], "Py": data1[:,1], "Pz": data1[:,2]})

# MMS1_n = pd.DataFrame({"times": times_n_mms1, "n": data_n_mms1})

# MMS1_Tpara = pd.DataFrame({"times": times_Tpara_mms1, "Tpara": data_Tpara_mms1})

# MMS1_Tperp = pd.DataFrame({"times": times_Tperp_mms1, "Tperp": data_Tperp_mms1})

# MMS1_V = pd.DataFrame({"times": times_v_mms1, "Vx": data_v_mms1[:,0],
#                    "Vy": data_v_mms1[:,1], "Vz": data_v_mms1[:,2]})
# #MMS1_B['date'] = pd.to_datetime(MMS1_B['times'],unit='s')
# MMS1_n['date'] = pd.to_datetime(MMS1_n['times'],unit='s')
# MMS1_Tpara['date'] = pd.to_datetime(MMS1_Tpara['times'],unit='s')
# MMS1_Tperp['date'] = pd.to_datetime(MMS1_Tperp['times'],unit='s')
# MMS1_V['date'] = pd.to_datetime(MMS1_V['times'],unit='s')


# #MMS1_B.to_csv('MMS1_B.csv', index=False)  
# MMS1_n.to_csv('MMS1_n.csv', index=False)  
# MMS1_Tpara.to_csv('MMS1_Tpara.csv', index=False)  
# MMS1_Tperp.to_csv('MMS1_Tperp.csv', index=False)  
# MMS1_V.to_csv('MMS1_V.csv', index=False)

# %%
# ion_vars = fpi(probe = 3,data_rate = 'brst',datatype = 'dis-moms',
#                    trange = trange, center_measurement = True)

# %%
# P_mms3 = 'mms3_dis_prestensor_gse_brst'
# times_p_mms3, data_p_mms3 = get_data(P_mms3)

# n_mms3 = 'mms3_dis_numberdensity_brst'
# times_n_mms3, data_n_mms3 = get_data(n_mms3)

# Tpara_mms3 = 'mms3_dis_temppara_brst'
# times_Tpara_mms3, data_Tpara_mms3 = get_data(Tpara_mms3)

# Tperp_mms3 = 'mms3_dis_tempperp_brst'
# times_Tperp_mms3, data_Tperp_mms3 = get_data(Tperp_mms3)

# V_mms3 = 'mms3_dis_bulkv_gse_brst'
# times_v_mms3, data_v_mms3 = get_data(V_mms3)





# # mms3 data for time period

# # mms3_B = pd.DataFrame({"times": times_b_mms3, "Bx": data_b_mms3[:,0],
# #                    "By": data_b_mms3[:,1], "Bz": data_b_mms3[:,2],"Bmag": data_b_mms3[:,3]})
# #mms3_P = pd.DataFrame({"times": times3, "Px": data3[:,0], "Py": data3[:,1], "Pz": data3[:,2]})

# MMS3_n = pd.DataFrame({"times": times_n_mms3, "n": data_n_mms3})

# MMS3_Tpara = pd.DataFrame({"times": times_Tpara_mms3, "Tpara": data_Tpara_mms3})

# MMS3_Tperp = pd.DataFrame({"times": times_Tperp_mms3, "Tperp": data_Tperp_mms3})

# MMS3_V = pd.DataFrame({"times": times_v_mms3, "Vx": data_v_mms3[:,0],
#                    "Vy": data_v_mms3[:,1], "Vz": data_v_mms3[:,2]})
# #MMS3_B['date'] = pd.to_datetime(MMS3_B['times'],unit='s')
# MMS3_n['date'] = pd.to_datetime(MMS3_n['times'],unit='s')
# MMS3_Tpara['date'] = pd.to_datetime(MMS3_Tpara['times'],unit='s')
# MMS3_Tperp['date'] = pd.to_datetime(MMS3_Tperp['times'],unit='s')
# MMS3_V['date'] = pd.to_datetime(MMS3_V['times'],unit='s')


# #MMS3_B.to_csv('MMS3_B.csv', index=False)  
# MMS3_n.to_csv('MMS3_n.csv', index=False)  
# MMS3_Tpara.to_csv('MMS3_Tpara.csv', index=False)  
# MMS3_Tperp.to_csv('MMS3_Tperp.csv', index=False)  
# MMS3_V.to_csv('MMS3_V.csv', index=False)

# %%
# ion_vars = fpi(probe = 4,data_rate = 'brst',datatype = 'dis-moms',
#                    trange = trange, center_measurement = True)

# P_mms4 = 'mms4_dis_prestensor_gse_brst'
# times_p_mms4, data_p_mms4 = get_data(P_mms4)

# n_mms4 = 'mms4_dis_numberdensity_brst'
# times_n_mms4, data_n_mms4 = get_data(n_mms4)

# Tpara_mms4 = 'mms4_dis_temppara_brst'
# times_Tpara_mms4, data_Tpara_mms4 = get_data(Tpara_mms4)

# Tperp_mms4 = 'mms4_dis_tempperp_brst'
# times_Tperp_mms4, data_Tperp_mms4 = get_data(Tperp_mms4)

# V_mms4 = 'mms4_dis_bulkv_gse_brst'
# times_v_mms4, data_v_mms4 = get_data(V_mms4)





# # mms4 data for time period

# # mms4_B = pd.DataFrame({"times": times_b_mms4, "Bx": data_b_mms4[:,0],
# #                    "By": data_b_mms4[:,1], "Bz": data_b_mms4[:,2],"Bmag": data_b_mms4[:,4]})
# #mms4_P = pd.DataFrame({"times": times4, "Px": data4[:,0], "Py": data4[:,1], "Pz": data4[:,2]})

# MMS4_n = pd.DataFrame({"times": times_n_mms4, "n": data_n_mms4})

# MMS4_Tpara = pd.DataFrame({"times": times_Tpara_mms4, "Tpara": data_Tpara_mms4})

# MMS4_Tperp = pd.DataFrame({"times": times_Tperp_mms4, "Tperp": data_Tperp_mms4})

# MMS4_V = pd.DataFrame({"times": times_v_mms4, "Vx": data_v_mms4[:,0],
#                    "Vy": data_v_mms4[:,1], "Vz": data_v_mms4[:,2]})
# #MMS4_B['date'] = pd.to_datetime(MMS4_B['times'],unit='s')
# MMS4_n['date'] = pd.to_datetime(MMS4_n['times'],unit='s')
# MMS4_Tpara['date'] = pd.to_datetime(MMS4_Tpara['times'],unit='s')
# MMS4_Tperp['date'] = pd.to_datetime(MMS4_Tperp['times'],unit='s')
# MMS4_V['date'] = pd.to_datetime(MMS4_V['times'],unit='s')


# #MMS4_B.to_csv('MMS4_B.csv', index=False)  
# MMS4_n.to_csv('MMS4_n.csv', index=False)  
# MMS4_Tpara.to_csv('MMS4_Tpara.csv', index=False)  
# MMS4_Tperp.to_csv('MMS4_Tperp.csv', index=False)  
# MMS4_V.to_csv('MMS4_V.csv', index=False)

# %%
tplot_names()

# %%
# b_field_MMS1 = 'mms1_fgm_b_gse_brst_l2'

# times_b_MMS1, data_b_MMS1 = get_data(b_field_MMS1)

# P_MMS1 = 'mms1_dis_prestensor_gse_brst'
# times_p_MMS1, data_p_MMS1 = get_data(P_MMS1)

# n_MMS1 = 'mms1_dis_numberdensity_brst'
# times_n_MMS1, data_n_MMS1 = get_data(n_MMS1)

# Tpara_MMS1 = 'mms1_dis_temppara_brst'
# times_Tpara_MMS1, data_Tpara_MMS1 = get_data(Tpara_MMS1)

# Tperp_MMS1 = 'mms1_dis_tempperp_brst'
# times_Tperp_MMS1, data_Tperp_MMS1 = get_data(Tperp_MMS1)

# V_MMS1 = 'mms1_dis_bulkv_gse_brst'
# times_v_MMS1, data_v_MMS1 = get_data(V_MMS1)


# MMS1_B = pd.DataFrame({"times": times_b_MMS1, "Bx": data_b_MMS1[:,0],
#                    "By": data_b_MMS1[:,1], "Bz": data_b_MMS1[:,2],"Bmag": data_b_MMS1[:,3]})

# MMS1_n = pd.DataFrame({"times": times_n_MMS1, "n": data_n_MMS1})

# MMS1_Tpara = pd.DataFrame({"times": times_Tpara_MMS1, "Tpara": data_Tpara_MMS1})

# MMS1_Tperp = pd.DataFrame({"times": times_Tperp_MMS1, "Tperp": data_Tperp_MMS1})

# MMS1_V = pd.DataFrame({"times": times_v_MMS1, "Vx": data_v_MMS1[:,0],
#                    "Vy": data_v_MMS1[:,1], "Vz": data_v_MMS1[:,2]})


# b_field_mms2 = 'mms2_fgm_b_gse_brst_l2'
# times_b_mms2, data_b_mms2 = get_data(b_field_mms2)

# P_mms2 = 'mms2_dis_prestensor_gse_brst'
# times_p_mms2, data_p_mms2 = get_data(P_mms2)

# n_mms2 = 'mms2_dis_numberdensity_brst'
# times_n_mms2, data_n_mms2 = get_data(n_mms2)

# Tpara_mms2 = 'mms2_dis_temppara_brst'
# times_Tpara_mms2, data_Tpara_mms2 = get_data(Tpara_mms2)

# Tperp_mms2 = 'mms2_dis_tempperp_brst'
# times_Tperp_mms2, data_Tperp_mms2 = get_data(Tperp_mms2)

# V_mms2 = 'mms2_dis_bulkv_gse_brst'
# times_v_mms2, data_v_mms2 = get_data(V_mms2)



# # MMS2 data for time period

# MMS2_B = pd.DataFrame({"times": times_b_mms2, "Bx": data_b_mms2[:,0],
#                    "By": data_b_mms2[:,1], "Bz": data_b_mms2[:,2],"Bmag": data_b_mms2[:,3]})
# #MMS2_P = pd.DataFrame({"times": times3, "Px": data3[:,0], "Py": data3[:,1], "Pz": data3[:,2]})

# MMS2_n = pd.DataFrame({"times": times_n_mms2, "n": data_n_mms2})

# MMS2_Tpara = pd.DataFrame({"times": times_Tpara_mms2, "Tpara": data_Tpara_mms2})

# MMS2_Tperp = pd.DataFrame({"times": times_Tperp_mms2, "Tperp": data_Tperp_mms2})

# MMS2_V = pd.DataFrame({"times": times_v_mms2, "Vx": data_v_mms2[:,0],
#                    "Vy": data_v_mms2[:,1], "Vz": data_v_mms2[:,2]})



# b_field_mms3 = 'mms3_fgm_b_gse_brst_l2'
# times_b_mms3, data_b_mms3 = get_data(b_field_mms3)

# P_mms3 = 'mms3_dis_prestensor_gse_brst'
# times_p_mms3, data_p_mms3 = get_data(P_mms3)

# n_mms3 = 'mms3_dis_numberdensity_brst'
# times_n_mms3, data_n_mms3 = get_data(n_mms3)

# Tpara_mms3 = 'mms3_dis_temppara_brst'
# times_Tpara_mms3, data_Tpara_mms3 = get_data(Tpara_mms3)

# Tperp_mms3 = 'mms3_dis_tempperp_brst'
# times_Tperp_mms3, data_Tperp_mms3 = get_data(Tperp_mms3)

# V_mms3 = 'mms3_dis_bulkv_gse_brst'
# times_v_mms3, data_v_mms3 = get_data(V_mms3)



# # mms3 data for time period

# mms3_B = pd.DataFrame({"times": times_b_mms3, "Bx": data_b_mms3[:,0],
#                    "By": data_b_mms3[:,1], "Bz": data_b_mms3[:,2],"Bmag": data_b_mms3[:,3]})
# #mms3_P = pd.DataFrame({"times": times3, "Px": data3[:,0], "Py": data3[:,1], "Pz": data3[:,2]})

# mms3_n = pd.DataFrame({"times": times_n_mms3, "n": data_n_mms3})

# mms3_Tpara = pd.DataFrame({"times": times_Tpara_mms3, "Tpara": data_Tpara_mms3})

# mms3_Tperp = pd.DataFrame({"times": times_Tperp_mms3, "Tperp": data_Tperp_mms3})

# mms3_V = pd.DataFrame({"times": times_v_mms3, "Vx": data_v_mms3[:,0],
#                    "Vy": data_v_mms3[:,1], "Vz": data_v_mms3[:,2]})




# b_field_mms4 = 'mms4_fgm_b_gse_brst_l2'
# times_b_mms4, data_b_mms4 = get_data(b_field_mms4)

# P_mms4 = 'mms4_dis_prestensor_gse_brst'
# times_p_mms4, data_p_mms4 = get_data(P_mms4)

# n_mms4 = 'mms4_dis_numberdensity_brst'
# times_n_mms4, data_n_mms4 = get_data(n_mms4)

# Tpara_mms4 = 'mms4_dis_temppara_brst'
# times_Tpara_mms4, data_Tpara_mms4 = get_data(Tpara_mms4)

# Tperp_mms4 = 'mms4_dis_tempperp_brst'
# times_Tperp_mms4, data_Tperp_mms4 = get_data(Tperp_mms4)

# V_mms4 = 'mms4_dis_bulkv_gse_brst'
# times_v_mms4, data_v_mms4 = get_data(V_mms4)



# # mms4 data for time period

# mms4_B = pd.DataFrame({"times": times_b_mms4, "Bx": data_b_mms4[:,0],
#                    "By": data_b_mms4[:,1], "Bz": data_b_mms4[:,2],"Bmag": data_b_mms4[:,3]})
# #mms4_P = pd.DataFrame({"times": times3, "Px": data3[:,0], "Py": data3[:,1], "Pz": data3[:,2]})

# mms4_n = pd.DataFrame({"times": times_n_mms4, "n": data_n_mms4})

# mms4_Tpara = pd.DataFrame({"times": times_Tpara_mms4, "Tpara": data_Tpara_mms4})

# mms4_Tperp = pd.DataFrame({"times": times_Tperp_mms4, "Tperp": data_Tperp_mms4})

# mms4_V = pd.DataFrame({"times": times_v_mms4, "Vx": data_v_mms4[:,0],
#                    "Vy": data_v_mms4[:,1], "Vz": data_v_mms4[:,2]})

# #OMNI_B_GSE = pd.DataFrame({""})
# #     OMNI_Bx_GSE = 'BX_GSE'
# #     times_OMNI_Bx, data_OMNI_Bx = get_data(OMNI_Bx_GSE)

# #     OMNI_By_GSE = 'BY_GSE'
# #     times_OMNI_By, data_OMNI_By = get_data(OMNI_By_GSE)

# #     OMNI_Bz_GSE = 'BZ_GSE'
# #     times_OMNI_Bz, data_OMNI_Bz = get_data(OMNI_Bz_GSE)

# #     OMNI_Vx_GSE = 'VX_GSE'
# #     times_OMNI_Vx, data_OMNI_Vx = get_data(OMNI_Vx_GSE)

# #     OMNI_Vy_GSE = 'VY_GSE'
# #     times_OMNI_Vy, data_OMNI_Vy = get_data(OMNI_Vy_GSE)

# #     OMNI_Vz_GSE = 'VZ_GSE'
# #     times_OMNI_Vz, data_OMNI_Vz = get_data(OMNI_Vz_GSE)


# #     OMNI_IMF = 'IMF'
# #     times_OMNI_IMF, data_OMNI_IMF = get_data(OMNI_IMF)

# #     OMNI_flow_speed = 'flow_speed'
# #     times_flow_speed, data_flow_speed = get_data(OMNI_flow_speed)    


# #     #OMNI_B = pd.DataFrame({"times": times_OMNI_Bx, "Bx": data_OMNI_Bx, "By": data_OMNI_By, "Bz": data_OMNI_Bz})

# #     OMNI_IMF = pd.DataFrame({"times":times_OMNI_IMF,"IMF":data_OMNI_IMF})

# #     OMNI_flow_speed = pd.DataFrame({"times":times_flow_speed,"flow_speed":data_flow_speed})

# #     OMNI_IMF['date'] = pd.to_datetime(OMNI_IMF['times'],unit='s')
# #     OMNI_flow_speed['date'] = pd.to_datetime(OMNI_flow_speed['times'],unit='s')


# MMS1_B['date'] = pd.to_datetime(MMS1_B['times'],unit='s')
# MMS1_n['date'] = pd.to_datetime(MMS1_n['times'],unit='s')
# MMS1_Tpara['date'] = pd.to_datetime(MMS1_Tpara['times'],unit='s')
# MMS1_Tperp['date'] = pd.to_datetime(MMS1_Tperp['times'],unit='s')
# MMS1_V['date'] = pd.to_datetime(MMS1_V['times'],unit='s')


# MMS2_B['date'] = pd.to_datetime(MMS2_B['times'],unit='s')
# MMS2_n['date'] = pd.to_datetime(MMS2_n['times'],unit='s')
# MMS2_Tpara['date'] = pd.to_datetime(MMS2_Tpara['times'],unit='s')
# MMS2_Tperp['date'] = pd.to_datetime(MMS2_Tperp['times'],unit='s')
# MMS2_V['date'] = pd.to_datetime(MMS2_V['times'],unit='s')


# MMS3_B['date'] = pd.to_datetime(MMS3_B['times'],unit='s')
# MMS3_n['date'] = pd.to_datetime(MMS3_n['times'],unit='s')
# MMS3_Tpara['date'] = pd.to_datetime(MMS3_Tpara['times'],unit='s')
# MMS3_Tperp['date'] = pd.to_datetime(MMS3_Tperp['times'],unit='s')
# MMS3_V['date'] = pd.to_datetime(MMS3_V['times'],unit='s')

# MMS4_B['date'] = pd.to_datetime(MMS4_B['times'],unit='s')
# MMS4_n['date'] = pd.to_datetime(MMS4_n['times'],unit='s')
# MMS4_Tpara['date'] = pd.to_datetime(MMS4_Tpara['times'],unit='s')
# MMS4_Tperp['date'] = pd.to_datetime(MMS4_Tperp['times'],unit='s')
# MMS4_V['date'] = pd.to_datetime(MMS4_V['times'],unit='s')






# MMS2_B.to_csv('MMS2_B.csv', index=False)  
# MMS2_n.to_csv('MMS2_n.csv', index=False)  
# MMS2_Tpara.to_csv('MMS2_Tpara.csv', index=False)  
# MMS2_Tperp.to_csv('MMS2_Tperp.csv', index=False)  
# MMS2_V.to_csv('MMS2_V.csv', index=False)  

# MMS1_B.to_csv('MMS1_B.csv', index=False)  
# MMS1_n.to_csv('MMS1_n.csv', index=False)  
# MMS1_Tpara.to_csv('MMS1_Tpara.csv', index=False)  
# MMS1_Tperp.to_csv('MMS1_Tperp.csv', index=False)  
# MMS1_V.to_csv('MMS1_V.csv', index=False)  

# MMS3_B.to_csv('MMS3_B.csv', index=False)  
# MMS3_n.to_csv('MMS3_n.csv', index=False)  
# MMS3_Tpara.to_csv('MMS3_Tpara.csv', index=False)  
# MMS3_Tperp.to_csv('MMS3_Tperp.csv', index=False)  
# MMS3_V.to_csv('MMS3_V.csv', index=False)  

# MMS4_B.to_csv('MMS4_B.csv', index=False)  
# MMS4_n.to_csv('MMS4_n.csv', index=False)  
# MMS4_Tpara.to_csv('MMS4_Tpara.csv', index=False)  
# MMS4_Tperp.to_csv('MMS4_Tperp.csv', index=False)  
# MMS4_V.to_csv('MMS4_V.csv', index=False)

# %%
# fgm_vars = fgm(trange = trange, probe = 3, data_rate = 'brst')

# %%
# fgm_vars = fgm(trange = trange, probe = 1, data_rate = 'brst')
# b_field_mms1 = 'mms1_fgm_b_gse_brst_l2'
# times_b_mms1, data_b_mms1 = get_data(b_field_mms1)
# MMS1_B = pd.DataFrame({"times": times_b_mms1, "Bx": data_b_mms1[:,0],
#                    "By": data_b_mms1[:,1], "Bz": data_b_mms1[:,2],"Bmag": data_b_mms1[:,3]})
# MMS1_B['date'] = pd.to_datetime(MMS1_B['times'],unit='s')


# MMS1_B.to_csv('MMS1_B.csv', index=False)

# %%
# tplot(['mms2_fgm_b_gse_brst_l2','mms2_dis_numberdensity_brst','mms2_dis_temppara_brst',
#            'mms2_dis_tempperp_brst','mms2_dis_bulkv_gse_brst'])

# %%
# data = get_data('mms4_epd_feeps_srvy_l2_electron_intensity_omni_spin')
# data.v.shape
# data.v
# data.y.shape
# data.y[1002, :]

# %%
# fgm_vars = fgm(trange = trange, probe = 4, data_rate = 'brst')
# b_field_mms4 = 'mms4_fgm_b_gse_brst_l2'
# times_b_mms4, data_b_mms4 = get_data(b_field_mms4)
# MMS4_B = pd.DataFrame({"times": times_b_mms4, "Bx": data_b_mms4[:,0],
#                    "By": data_b_mms4[:,1], "Bz": data_b_mms4[:,2],"Bmag": data_b_mms4[:,3]})
# MMS4_B['date'] = pd.to_datetime(MMS4_B['times'],unit='s')


# MMS4_B.to_csv('MMS4_B.csv', index=False)

# %%
# b_field_mms2 = 'mms'+probe[0]+'_fgm_b_gse_brst_l2'
# times_b, data_b = get_data(b_field_mms2)


    
# store_data('Bx_GSE', data = {'Bx': times_b, 'y': data_b[:,0]})
# store_data('By_GSE', data = {'By': times_b, 'y': data_b[:,1]})
# store_data('Bz_GSE', data = {'Bz': times_b, 'y': data_b[:,2]})

# V = 'mms2_dis_bulkv_gse_brst'
# times_v, data_v = get_data(V)


    
# store_data('Vx_GSE', data = {'Vx': times_v, 'y': data_v[:,0]})
# store_data('Vy_GSE', data = {'Vy': times_v, 'y': data_v[:,1]})
# store_data('Vz_GSE', data = {'Vz': times_v, 'y': data_v[:,2]})

# %% [markdown]
# ## Use curlometer

# %%
#from pyspedas.analysis.tcrossp import tcrossp
from pyspedas.analysis.tdotp import tdotp


tdotp('mms2_fgm_b_gse_brst_l2_bvec', 'mms2_fgm_b_gse_brst_l2_bvec')
tplot('mms2_fgm_b_gse_brst_l2_bvec_dot_mms2_fgm_b_gse_brst_l2_bvec')

# %%
tcrossp('mms1_fgm_b_gse_brst_l2_bvec', 'mms1_fgm_b_gse_brst_l2_bvec')
tplot('mms1_fgm_b_gse_brst_l2_bvec_cross_mms1_fgm_b_gse_brst_l2_bvec')

# %%
from pyspedas.mms import curlometer

# %%
help(curlometer)

# %%
curlometer(fields=['mms2_fgm_b_gse_brst_l2_bvec'],
           positions=['mms2_mec_r_gse'])

# %%
tplot(['jtotal', 'mms1_fgm_b_gse_brst_l2_bvec', 'mms2_fgm_b_gse_brst_l2_bvec', 'mms3_fgm_b_gse_brst_l2_bvec', 'mms4_fgm_b_gse_brst_l2_bvec'])

# %%
# MMS2_B.to_csv('MMS2_B.csv', index=False)  
# MMS2_n.to_csv('MMS2_n.csv', index=False)  
# MMS2_Tpara.to_csv('MMS2_Tpara.csv', index=False)  
# MMS2_Tperp.to_csv('MMS2_Tperp.csv', index=False)  
# MMS2_V.to_csv('MMS2_V.csv', index=False)

# %% [markdown]
# ### Trim data if desired

# %%
#     st_time = pd.to_datetime("2020-06-17/18:00:00")
#     end_time = pd.to_datetime("2020-06-18/07:00:00")

#     st_idx_B = MMS2_B.date.searchsorted(st_time)
#     end_idx_B = MMS2_B.date.searchsorted(end_time)

#     st_idx_n = MMS2_n.date.searchsorted(st_time)
#     end_idx_n = MMS2_n.date.searchsorted(end_time)


#     st_idx_Tpara = MMS2_Tpara.date.searchsorted(st_time)
#     end_idx_Tpara = MMS2_Tpara.date.searchsorted(end_time)


#     st_idx_Tperp = MMS2_Tperp.date.searchsorted(st_time)
#     end_idx_Tperp = MMS2_Tperp.date.searchsorted(end_time)


#     st_idx_V = MMS2_V.date.searchsorted(st_time)
#     end_idx_V = MMS2_V.date.searchsorted(end_time)


# #     print(st_idx_n)
# #     print(end_idx_n)

# #     print(st_idx_B)
# #     print(end_idx_B)


# #     print(st_idx_Tpara)
# #     print(end_idx_Tpara)

# #     print(st_idx_Tperp)
# #     print(end_idx_Tperp)

# #     print(st_idx_V)
# #     print(end_idx_V)


#     MMS2_n = pd.DataFrame({"times": times_n[st_idx_n:end_idx_n], "n": data_n[st_idx_n:end_idx_n]})

#     MMS2_Tpara = pd.DataFrame({"times": times_Tpara[st_idx_Tpara:end_idx_Tpara],
#                                "Tpara": data_Tpara[st_idx_Tpara:end_idx_Tpara]})

#     MMS2_Tperp = pd.DataFrame({"times": times_Tperp[st_idx_Tperp:end_idx_Tperp],
#                                "Tperp": data_Tperp[st_idx_Tperp:end_idx_Tperp]})

#     dvx = data_v[:,0]
#     dvy = data_v[:,1]
#     dvz = data_v[:,2]
#     dbx = data_b[:,0]
#     dby = data_b[:,1]
#     dbz = data_b[:,2]

#     MMS2_V = pd.DataFrame({"times": times_v[st_idx_V:end_idx_V], "Vx": dvx[st_idx_V:end_idx_V],
#                            "Vy": dvy[st_idx_V:end_idx_V], "Vz": dvz[st_idx_V:end_idx_V]})
#     MMS2_B = pd.DataFrame({"times": times_b[st_idx_B:end_idx_B], "Bx": dbx[st_idx_B:end_idx_B],
#                            "By": dby[st_idx_B:end_idx_B], "Bz": dbz[st_idx_B:end_idx_B]})


#     MMS2_B['date'] = pd.to_datetime(MMS2_B['times'],unit='s')
#     MMS2_n['date'] = pd.to_datetime(MMS2_n['times'],unit='s')
#     MMS2_Tpara['date'] = pd.to_datetime(MMS2_Tpara['times'],unit='s')
#     MMS2_Tperp['date'] = pd.to_datetime(MMS2_Tperp['times'],unit='s')
#     MMS2_V['date'] = pd.to_datetime(MMS2_V['times'],unit='s')

# %% [markdown]
# ## Load previously loaded pySPEDAS data that is time clipped and saved to csv (fastest method to plot)

# %%
# read in data saved as .csv files because the load routines are slow.

#dtype ={'times':np.float64,'Bx':np.float32,'By':np.float32,'Bz':float32}

if use_spedas == 'no':
    MMS2_B = pd.read_csv('MMS2_B.csv',header = 0,names = ['times','Bx','By','Bz','date'],
                         parse_dates=['date'])

    
    MMS2_V = pd.read_csv('MMS2_V.csv',
                         header = 0,names = ['times','Vx','Vy','Vz','date'],
                         parse_dates=['date'])
    
    MMS2_n = pd.read_csv('MMS2_n.csv',
                         header = 0,names = ['times','n','date'],
                         parse_dates=['date'])
    
    MMS2_Tperp = pd.read_csv('MMS2_Tperp.csv',
                         header = 0,names = ['times','Tperp','date'],
                         parse_dates=['date'])
    
    MMS2_Tpara = pd.read_csv('MMS2_Tpara.csv',
                         header = 0,names = ['times','Tpara','date'],
                         parse_dates=['date'])
    

MMS2_B

# %% [markdown]
# ### Trim B-field data so the interactive plot won't be so slow

# %%
# # (B-field is a lot of data and makes everything slow)

# st_time = pd.to_datetime("2020-06-17/22:30:00")
# end_time = pd.to_datetime("2020-06-18/00:30:00")



# # MMS2_B2 = pd.read_csv('MMS2_B.csv',header = 0,names = ['times','Bx','By','Bz','date'],
# #                          parse_dates=['date'])


# st_idx_B = MMS2_B.date.searchsorted(st_time)
# end_idx_B = MMS2_B.date.searchsorted(end_time)


# print(st_idx_B)

# print(end_idx_B)

# # dby = data_b[:,1]
# # dbz = data_b[:,2]

# MMS2_B_trimmed = pd.DataFrame({"date": MMS2_B['date'][st_idx_B:end_idx_B], "Bx": MMS2_B['Bx'][st_idx_B:end_idx_B],
#                            "By": MMS2_B['By'][st_idx_B:end_idx_B], "Bz": MMS2_B['Bz'][st_idx_B:end_idx_B]})

# #MMS2_B_trimmed
# #Audio(sound_file, autoplay=True)

# %% [markdown]
# ## Matplotlib Timeseries Plotting

# %%
# # Matplotlib plotting
# %matplotlib widget


# fig = plt.figure(figsize=(10,10))
# plt.rcParams.update({'font.size': 12})



# # Bx GSE
# ax_Bx = fig.add_subplot(911)
# #ax_Bx.set_title('Raw Data')
# ax_Bx.plot(MMS2_B_trimmed['date'],MMS2_B_trimmed['Bx'], label='$B_x$', color ='black')
# ax_Bx.set_ylabel('$B_x$ (GSE) \n [nT]')
# ax_Bx.grid('on')
# #ax_Bx.set_xticklabels([])


# #Vx GSE
# ax_Vx = fig.add_subplot(912,sharex = ax_Bx)
# #ax_Vx.set_title('Raw Data')
# ax_Vx.plot(MMS2_V['date'],MMS2_V['Vx'], label='$V_x$', color ='black')
# ax_Vx.set_ylabel('$V_x$ (GSE) \n [km s$^{-1}$]')
# ax_Vx.grid('on')
# ax_Vx.set_ylim([-75,75])
# # By GSE
# ax_By = fig.add_subplot(913,sharex = ax_Bx)
# ax_By.plot(MMS2_B_trimmed['date'],MMS2_B_trimmed['By'], label='$B_y$', color ='darkturquoise')
# ax_By.set_ylabel('$B_y$ (GSE) \n [nT]')
# ax_By.grid('on')

# #Vy GSE
# ax_Vy = fig.add_subplot(914,sharex = ax_Bx)
# ax_Vy.plot(MMS2_V['date'],MMS2_V['Vy'], label='$V_y$', color ='darkturquoise')
# ax_Vy.set_ylabel('$V_y$ (GSE) \n [km s$^{-1}$]')
# ax_Vy.grid('on')
# #ax_Vy.set_ylim([-50,50]
# #Bz GSE
# ax_Bz = fig.add_subplot(915,sharex = ax_Bx)
# ax_Bz.plot(MMS2_B_trimmed['date'],MMS2_B_trimmed['Bz'], label='$B_z$', color ='rebeccapurple')
# ax_Bz.set_ylabel('$B_z$ (GSE) \n [nT]')
# ax_Bz.grid('on')





# #Vz GSE
# ax_Vz = fig.add_subplot(916,sharex = ax_Bx)
# ax_Vz.plot(MMS2_V['date'],MMS2_V['Vz'], label='$V_z$', color ='rebeccapurple')
# ax_Vz.set_ylabel('$V_z$ (GSE) \n [km s$^{-1}$]')
# ax_Vz.grid('on')

# # ion density
# ax_n = fig.add_subplot(917,sharex = ax_Bx)
# ax_n.plot(MMS2_n['date'],MMS2_n['n'], label='$n$',color = 'maroon')
# ax_n.set_ylabel('n \n [cm$^{-3}$]')
# ax_n.grid('on')
# #ax_n.set_xticklabels([])



# # ion parallel and perpendicular temperature
# ax_T = fig.add_subplot(918,sharex = ax_Bx)
# ax_T.plot(MMS2_Tperp['date'],MMS2_Tperp['Tperp'], label='$T_{⊥}$',color ='plum')
# ax_T.plot(MMS2_Tpara['date'],MMS2_Tpara['Tpara'], label='$T_{||}$',color ='seagreen')
# ax_T.set_ylabel('$T$ \n [eV]')
# ax_T.grid('on')
# ax_T.legend(loc='center right',fontsize='small')



# # ax_IMF = fig.add_subplot(918,sharex = ax_Bx)
# # ax_IMF.plot(OMNI_IMF['date'],OMNI_IMF['IMF'], label='IMF',color ='darkgray')
# # #ax_IMF.plot(OMNI_flow_['date'],OMNI_IMF['IMF'], label='$T_{||}$',color ='seagreen')
# # ax_IMF.set_ylabel('IMF ')
# # ax_IMF.grid('on')
# # #x_IMF.legend(loc='center right',fontsize='small')




# # #ax1.set_xticks([])
# # plt.grid('on')
# # plt.legend()
# # ax2 = fig.add_subplot(512)
# # ax2.plot(MMS2_n['date'],MMS2_n['n'], label='$n$')
# # ax2.set_ylabel('n \n [cm$^{-3}$]')
# # ax2.grid('on')
# # #ax2.set_xticks([])
# # #plt.grid('on')
# # ax3 = fig.add_subplot(513)
# # ax3.plot(MMS2_Tpara['date'],MMS2_Tpara['Tpara'], label='$T_{||}$')
# # ax3.set_ylabel('$T_{||}$ \n [eV]')
# # ax3.grid('on')
# # #ax3.set_xticks([])
# # #plt.grid('on')
# # ax4 = fig.add_subplot(514)
# # ax4.plot(MMS2_Tperp['date'],MMS2_Tperp['Tperp'], label='$T_{⊥}$')
# # ax4.set_ylabel('$T_{⊥}$ \n [eV]')
# # ax4.grid('on')
# # #ax4.set_xticks([])
# # #plt.grid('on')
# # ax5 = fig.add_subplot(515)
# # ax5.plot(MMS2_V['date'],MMS2_V['Vx'], label='$V_x$')
# # ax5.plot(MMS2_V['date'],MMS2_V['Vy'], label='$V_y$')
# # ax5.plot(MMS2_V['date'],MMS2_V['Vz'], label='$V_z$')
# # ax5.set_ylabel('$V}$ \n [km s$^{-1}$]')
# # ax5.grid('on')

# plt.subplots_adjust(hspace=0.0)

# #plt.legend()
# #plt.grid('on')

# plt.show()
# # plt.close()
# #fig.savefig('Full_time_period_data')

# %%
# fft of density get 22:30-00:30 to get wavelength of KH

# %%
# fig = plt.figure(figsize=(10,8))
# plt.rcParams.update({'font.size': 12})
# ax1 = fig.add_subplot(511)
# ax1.plot(MMS2_B_trimmed['date'],MMS2_B_trimmed['Bx'], label='$B_x$')
# ax1.plot(MMS2_B_trimmed['date'],MMS2_B_trimmed['By'], label='$B_y$')
# ax1.plot(MMS2_B_trimmed['date'],MMS2_B_trimmed['Bz'], label='$B_z$')
# ax1.set_ylabel('B \n [nT]')
# ax1.set_ylim([-15,15])
# ax1.set_title('Raw Data')
# ax1.grid('on')
# #ax1.set_xticks([])
# ax1.legend(loc='center right',fontsize='small')




# ax2 = fig.add_subplot(512,sharex=ax1)
# ax2.plot(MMS2_n['date'],MMS2_n['n'], label='$n$')
# ax2.set_ylabel('n \n [cm$^{-3}$]')
# ax2.grid('on')
# #ax2.set_xticks([])
# ax2.set_ylim([0,10])


# #plt.grid('on')
# ax3 = fig.add_subplot(513,sharex=ax1)
# ax3.plot(MMS2_Tpara['date'],MMS2_Tpara['Tpara'], label='$T_{||}$')
# ax3.set_ylabel('$T_{||}$ \n [eV]')
# ax3.grid('on')
# #ax3.set_xticks([])
# #plt.grid('on')
# ax4 = fig.add_subplot(514,sharex=ax1)
# ax4.plot(MMS2_Tperp['date'],MMS2_Tperp['Tperp'], label='$T_{⊥}$')
# ax4.set_ylabel('$T_{⊥}$ \n [eV]')
# ax4.grid('on')
# #ax4.set_xticks([])
# #plt.grid('on')
# ax5 = fig.add_subplot(515,sharex=ax1)
# ax5.plot(MMS2_V['date'],MMS2_V['Vx'], label='$V_x$')
# ax5.plot(MMS2_V['date'],MMS2_V['Vy'], label='$V_y$')
# ax5.plot(MMS2_V['date'],MMS2_V['Vz'], label='$V_z$')
# ax5.set_ylabel('$V}$ \n [km s$^{-1}$]')
# ax5.grid('on')
# ax5.legend(loc='center right',fontsize='small')

# plt.subplots_adjust(hspace=0.05)



# # # Matplotlib Scatter Plot
# # plt.scatter(‘total_bill’, ‘tip’,data=df)
# # plt.xlabel(‘Total Bill’)
# # plt.ylabel(‘Tip’)
# # plt.show()

# %%
# MMS2_n
# # Check data types
# print(MMS2_n.dtypes)




# MMS2_n['date'] = pd.to_datetime(MMS2_n['times'],unit='s')


# #MMS2_n = MMS2_n.set_index('date')

# MMS2_nn = MMS2_n.n
# #MMS2_nn = pd.Series(MMS2_n['n'],name='n')



# MMS2_nn.plot(figsize =(14,6))
# plt.xlabel('Hours')
# plt.ylabel('Ion density')
# plt.grid(which='both', alpha=0.2)
# plt.show()

# %% [markdown]
# ### Check data for missing values

# %%
# # # Check for missing values
# missing = MMS2_nn.isna().sum()

# if missing != 0:
    
#     # Imputation of constant value
#     MMS2_nn = MMS2_nn.fillna(0)

#     # Mean imputation
#     MMS2_nn = MMS2_nn.fillna(MMS2_nn.mean())

#     # Backward-fill imputation (or last observation carried forward)
#     MMS2_nn = MMS2_nn.bfill()

#     # Linear interpolation
#     MMS2_nn = MMS2_nn.interpolate(method='linear')

# %%
# # Take the first difference of the data to remove the trend
# MMS2_nn = MMS2_nn.diff()

# # Drop the first NaN value coming from taking the difference 
# MMS2_nn = MMS2_nn.dropna()

# # Plot the data to see the outcome
# MMS2_nn.plot(figsize=(15,5))
# plt.xlabel('Date')
# plt.ylabel('Density increase rate')
# plt.grid()
# plt.show()

# %%
# # Calculate mean and standard deviation
# mean_n = MMS2_nn.mean()
# std_n = MMS2_nn.std()

# # Normalize data
# MMS2_nn = (MMS2_nn - mean_n) / std_n

# %%
# # Import library
# from sklearn.preprocessing import StandardScaler

# # Create a StandardScaler object
# scaler = StandardScaler()

# # Convert data to numpy array and reshape
# array_n = MMS2_nn.values.reshape(-1, 1)

# # Fit the scaler to the data and transform it
# data_scaled_n = scaler.fit_transform(array_n)

# # Convert back to pandas Series
# MMS2_nn = pd.Series(data_scaled_n.flatten(), 
#                     index = MMS2_nn.index, name = 'Time')

# %%
# MMS2_nn.plot(figsize = (14,6))
# plt.xlabel('Date')
# plt.ylabel('Normalized Ion density')
# plt.grid()
# plt.show()

# %%
# # plot box plots to observe any outliers

# #print(MMS2_n.shape)


# MMS2_n = pd.DataFrame({"times": times_n[st_idx_n:end_idx_n], "n": data_n[st_idx_n:end_idx_n]})
# MMS2_n['date'] = pd.to_datetime(MMS2_n['times'],unit = 's')
# MMS2_n.set_index('date')
# #MMS2_nnn = pd.DataFrame(MMS2_n['date'],MMS2_n['n'],rounded_hours)
# rounded_hours_n = MMS2_n.date.round('min')
# MMS2_nnn = pd.DataFrame({'date':MMS2_n.date,'time':MMS2_n.times,'rounded_time':rounded_hours_n, 'n':MMS2_n.n})
# MMS2_nnn.set_index('rounded_time')

# MMS2_Tperp = pd.DataFrame({"times": times_Tperp[st_idx_Tperp:end_idx_Tperp], "Tperp": data_Tperp[st_idx_Tperp:end_idx_Tperp]})
# MMS2_Tperp['date'] = pd.to_datetime(MMS2_Tperp['times'],unit = 's')
# MMS2_Tperp.set_index('date')
# rounded_hours_Tperp = MMS2_Tperp.date.round('min')
# MMS2_Tperp2 = pd.DataFrame({'date':MMS2_Tperp.date,'time':MMS2_Tperp.times,
#                            'rounded_time':rounded_hours_Tperp, 'Tperp':MMS2_Tperp.Tperp})
# MMS2_Tperp2.set_index('rounded_time')

# # # for each half hour, make a boxplot of those n values. 
# # t1 = pd.date_range('2020-06-17/20:30:00','2020-06-18/01:00:00',freq='30min')
# # t2 = pd.date_range('2020-06-17/21:00:00','2020-06-18/01:30:00',freq='30min')

# # # print(t1.shape)

# # # print(t2.shape)


# # #for k in range(len(MMS2_nn.unique)):

# # #fig = plt.figure(figsize=(10,6))
# # st_indices_n=[]
# # end_indices_n=[]
# # for t in range(len(t1)):
# #     st_indices_n.append(MMS2_n.date.searchsorted(t1[t]))
# #     end_indices_n.append(MMS2_n.date.searchsorted(t2[t]))
# #     MMS2_n.n[MMS2_n.date.searchsorted(t1[t]):MMS2_n.date.searchsorted(t2[t])].plot.box()
    


# # MMS2_Tperp = pd.DataFrame({"times": times_Tperp[st_idx_Tperp:end_idx_Tperp], "Tperp": data_Tperp[st_idx_Tperp:end_idx_Tperp]})
# # MMS2_Tperp['date'] = pd.to_datetime(MMS2_Tperp['times'],unit = 's')
# # MMS2_Tperp.set_index('date')
# # #MMS2_Tperpnn = pd.DataFrame(MMS2_Tperp['date'],MMS2_Tperp['n'],rounded_hours)


# # rounded_hours = MMS2_Tperp.date.round('min')
# # MMS2_Tperp = pd.DataFrame({'date':MMS2_Tperp.date,'time':MMS2_Tperp.times,
# #                            'rounded_time':rounded_hours, 'Tperp':MMS2_Tperp.Tperp})


# # # #MMS2_Tperpnn.set_index('rounded_time')


# # # # for each half hour, make a boxplot of those n values. 
# # # # t1 = pd.date_range('2020-06-17/20:30:00','2020-06-18/01:00:00',freq='30min')
# # # # t2 = pd.date_range('2020-06-17/21:00:00','2020-06-18/01:30:00',freq='30min')

# # # # print(t1.shape)

# # # # print(t2.shape)


# # # #for k in range(len(MMS2_Tperpn.unique)):

# # # #fig = plt.figure(figsize=(10,6))
# # # st_indices_Tperp=[]
# # # end_indices_Tperp=[]
# # # for t in range(len(t1)):
# # #     st_indices_Tperp.append(MMS2_Tperp.date.searchsorted(t1[t]))
# # #     end_indices_Tperp.append(MMS2_Tperp.date.searchsorted(t2[t]))
# # #     MMS2_Tperp.n[MMS2_Tperp.date.searchsorted(t1[t]):MMS2_Tperp.date.searchsorted(t2[t])].plot.box()
        

# # # # for k in 

    
# # # # cat1 = MMS2_n.n[MMS2_n.date.searchsorted(t1[t]):MMS2_n.date.searchsorted(t2[t])] 
# # # # # r = pd.date_range(MMS2_n.date)







# # # # for k 



# # # #MMS2_n['date'] = pd.to_datetime(MMS2_n['times'],unit='s')


# # # #MMS2_n = MMS2_n.set_index('date')

# # # #MMS2_nn = MMS2_n.n

# # # # print(r)



# # # # Try to get .between_time to work in the future. 

# # # #for dt in range(len(t1)):
# # #     #MMS2_nnn.between_time(t1[dt],t2[dt]).plot.box()
   



# # # # st_time = pd.to_datetime("2020-06-17/20:30:00")

# # # # end_time = pd.to_datetime("2020-06-18/01:30:00")



# # # # a.shape
# # # #MMS2_nnn.indexer_between_time('0:00','0:30')
# # # #rounded_hours
# # #     # Group by month
# # # # MMS2_n.unstack().plot.box()
# # # # #MMS2_nn.set_index('date')
# # # #MMS2_nnn.n.plot.box()


# # # # #plt.xlabel('Month')
# # # # plt.ylabel('Ion Density')
# # # # plt.grid(which='both', alpha=0.2)
# # # # plt.show()

# %%
# # Remove outliers according to month
# #MMS2_nn['n']



# abnormal_values_dates_Tperp = []

# abnormal_values_dates_n = []

# for t in t1:
#     # Group values by 30mins
#     df_date_n = MMS2_nnn[MMS2_nnn.rounded_time == MMS2_nnn.rounded_time[MMS2_nnn.rounded_time.searchsorted(t)]]
#     #print(df_date_n)
#     # Calculate Q1, Q3 and interquartile range
#     q1_n = df_date_n.n.quantile(0.25)
#     q3_n = df_date_n.n.quantile(0.75)
#     iqr_n = q3_n - q1_n
    
#     # Find anomalies
#     abnormal_dates_n = df_date_n[(df_date_n.n < q1_n - 1.5 * iqr_n) \
#                          | (df_date_n.n > q3_n + 1.5 * iqr_n)].index
#     print(abnormal_dates_n)
    
#     # Add anomalies to list
#     if not abnormal_dates_n.empty:
#         abnormal_values_dates_n = abnormal_values_dates_n + list(abnormal_dates_n)
        
#      # Group values by 30mins
#     df_date_Tperp = MMS2_Tperp2[MMS2_Tperp2.rounded_time == MMS2_Tperp2.rounded_time[MMS2_Tperp2.rounded_time.searchsorted(t)]]
#     #print(df_date_Tperp)
#     # Calculate Q1, Q3 and interquartile range
#     q1_Tperp = df_date_Tperp.Tperp.quantile(0.25)
#     q3_Tperp = df_date_Tperp.Tperp.quantile(0.75)
#     iqr_Tperp = q3_Tperp - q1_Tperp
    
#     # Find anomalies
#     abnormal_dates_Tperp = df_date_Tperp[(df_date_Tperp.Tperp < q1_Tperp - 1.5 * iqr_Tperp) \
#                          | (df_date_Tperp.Tperp > q3_Tperp + 1.5 * iqr_Tperp)].index
    
#     # Add anomalies to list
#     if not abnormal_dates_Tperp.empty:
#         abnormal_values_dates_Tperp = abnormal_values_dates_Tperp + list(abnormal_dates_Tperp)
           
# # print(abnormal_values_dates_n)
        
# # print(abnormal_values_date_Tperp)
        
# # print(abnormal_values_dates_Tperp)
# # abnormal_values_dates_n = []

# # abnormal_values_dates_Tperp = []


        
# #print(abnormal_values_dates_n)

# %%
# # Define the z-score function
# def zscore(x, window):
#     r = x.rolling(window=window)
#     m = r.mean().shift(1)
#     s = r.std(ddof=0).shift(1)
#     z = (x-m)/s
#     return z
    
# # Calculate zscore with a rolling window and get abnormal values
# window_size = 5 
# df_zscore_n = zscore(MMS2_nnn.n, window_size)

# times_n = pd.date_range('2020-06-17/20:00:00','2020-06-18/01:30:00',periods=len(df_zscore_n))


# df_zscore_n1 = pd.DataFrame({'n':df_zscore_n,'times':times_n})
# # Apply a threshold for the z-score set it to every ___ minutes
# threshold = 15
# abnormal_values_dates_n = df_zscore_n[abs(df_zscore_n1.n) > threshold ].index


# # MMS2_nn.plot(figsize =(14,6))
# df_zscore_Tperp = zscore(MMS2_Tperp2.Tperp, 4)

# times_Tperp = pd.date_range('2020-06-17/20:00:00','2020-06-18/01:30:00',periods=len(df_zscore_Tperp))


# df_zscore_Tperp1 = pd.DataFrame({'Tperp':df_zscore_Tperp,'times':times_Tperp})
# # Apply a threshold for the z-score set it to every ___ minutes

# threshold_Tperp = 20
# abnormal_values_dates_Tperp = df_zscore_Tperp[abs(df_zscore_Tperp1.Tperp) > threshold_Tperp ].index

# plt.rcParams.update({'font.size': 18})
# plt.figure(figsize=(20,6))
# plt.plot(times_n, df_zscore_n)
# plt.title('Outliers in Density dataset')
# plt.xlabel('Time Stamp')
# plt.ylabel('Z-score')
# plt.axhline(y = threshold,color='purple',linestyle='-', label='threshold')
# plt.axhline(y = -threshold,color='purple',linestyle='-')
# plt.grid()
# plt.legend()
# plt.show




# plt.rcParams.update({'font.size': 18})
# plt.figure(figsize=(20,6))
# plt.plot(times_Tperp, df_zscore_Tperp)
# plt.title('Outliers in $T_{⊥}$ dataset')
# plt.xlabel('Time Stamp')
# plt.ylabel('Z-score')
# plt.axhline(y = threshold_Tperp,color='purple',linestyle='-', label='threshold')
# plt.axhline(y = -threshold_Tperp,color='purple',linestyle='-')
# plt.grid()
# plt.legend()
# plt.show()

# %%
# outliers removal

# %%
# # Set anomalies to NaN
# MMS2_nnn.loc[abnormal_values_dates_n, 'n'] = np.nan

# # impution method of linear interpolation
# # Interpolate
# MMS2_nnn = MMS2_nnn.interpolate()



# # Set anomalies to NaN
# MMS2_Tperp.loc[abnormal_values_dates_Tperp, 'Tperp'] = np.nan

# # impution method of linear interpolation
# # Interpolate
# MMS2_Tperp = MMS2_Tperp.interpolate()

# %%
# # plot cleaned density 
# fig = plt.figure(figsize=(20,6))
# plt.rcParams.update({'font.size': 10})
# ax1 = fig.add_subplot(511)
# ax1.plot(MMS2_B['date'],MMS2_B['Bx'], label='$B_x$')
# ax1.plot(MMS2_B['date'],MMS2_B['By'], label='$B_y$')
# ax1.plot(MMS2_B['date'],MMS2_B['Bz'], label='$B_z$')
# ax1.set_ylabel('B \n [nT]')
# ax1.set_ylim([-15,15])
# ax1.set_title('Cleaned Data')
# #ax1.set_xticks([])
# #plt.grid('on')
# plt.legend()
# ax2 = fig.add_subplot(512)
# ax2.plot(MMS2_nnn['date'],MMS2_nnn['n'], label='$n$')
# ax2.set_ylabel('n \n [cm$^{-3}$]')
# #ax2.set_xticks([])
# #plt.grid('on')
# ax3 = fig.add_subplot(513)
# ax3.plot(MMS2_Tpara['date'],MMS2_Tpara['Tpara'], label='$T_{||}$')
# ax3.set_ylabel('$T_{||}$ \n [eV]')
# #ax3.set_xticks([])
# #plt.grid('on')
# ax4 = fig.add_subplot(514)
# ax4.plot(MMS2_Tperp2['date'],MMS2_Tperp2['Tperp'], label='$T_{⊥}$')
# ax4.set_ylabel('$T_{⊥}$ \n [eV]')
# #ax4.set_xticks([])
# #plt.grid('on')
# ax5 = fig.add_subplot(515)
# ax5.plot(MMS2_V['date'],MMS2_V['Vx'], label='$V_x$')
# ax5.plot(MMS2_V['date'],MMS2_V['Vy'], label='$V_y$')
# ax5.plot(MMS2_V['date'],MMS2_V['Vz'], label='$V_z$')
# ax5.set_ylabel('$V}$ \n [km s$^{-1}$]')

# plt.subplots_adjust(hspace=0.0)

# #plt.legend()
# #plt.grid('on')

# plt.show()

# %%
# def fft_denoiser(x, n_components, to_real=True):
#     """Fast fourier transform denoiser.
    
#     Denoises data using the fast fourier transform.
    
#     Parameters
#     ----------
#     x : numpy.array
#         The data to denoise.
#     n_components : int
#         The value above which the coefficients will be kept.
#     to_real : bool, optional, default: True
#         Whether to remove the complex part (True) or not (False)
        
#     Returns
#     -------
#     clean_data : numpy.array
#         The denoised data.
        
#     References
#     ----------
#     .. [1] Steve Brunton - Denoising Data with FFT[Python]
#        https://www.youtube.com/watch?v=s2K1JfNR7Sc&ab_channel=SteveBrunton
    
#     """
#     n = len(x)
    
#     # compute the fft
#     fft = np.fft.fft(x, n)
    
#     # compute power spectrum density
#     # squared magnitud of each fft coefficient
#     PSD = fft * np.conj(fft) / n
    
#     # keep high frequencies
#     _mask = PSD > n_components
#     fft = _mask * fft
    
#     # inverse fourier transform
#     clean_data = np.fft.ifft(fft)
    
#     if to_real:
#         clean_data = clean_data.real
    
#     return clean_data

# %%
# new_Bx = fft_denoiser(MMS2_B['Bx'], 2, to_real=True)

# MMS2_denoised_B = pd.DataFrame({"times": times_b, "Bx": fft_denoiser(MMS2_B['Bx'], 2, to_real=True),
#                                 "By": fft_denoiser(MMS2_B['By'], 2, to_real=True),
#                                 "Bz": fft_denoiser(MMS2_B['Bz'], 2, to_real=True),
#                    "Bmag": fft_denoiser(MMS2_B['Bmag'], 2, to_real=True)})





# MMS2_denoised_V = pd.DataFrame({"times": times_v, "Vx": fft_denoiser(MMS2_V['Vx'], 3, to_real=True),
#                                 "Vy": fft_denoiser(MMS2_V['Vy'], 2, to_real=True),
#                                 "Vz": fft_denoiser(MMS2_V['Vz'], 2, to_real=True)})

# MMS2_denoised_n = pd.DataFrame({"times": times_n, "n": fft_denoiser(MMS2_n['n'], 3, to_real=True)})

# MMS2_denoised_Tpara = pd.DataFrame({"times": times_Tpara, "Tpara": fft_denoiser(MMS2_Tpara['Tpara'], 5, to_real=True)})
# MMS2_denoised_Tperp = pd.DataFrame({"times": times_Tperp, "Tperp": fft_denoiser(MMS2_Tperp['Tperp'], 5, to_real=True)})




# MMS2_denoised_B['date']=MMS2_B['date']


# MMS2_denoised_n['date']= MMS2_n['date']
# MMS2_denoised_Tpara['date']=MMS2_Tpara['date']
# MMS2_denoised_Tperp['date']=MMS2_Tperp['date']
# MMS2_denoised_V['date']=MMS2_V['date']

# fig = plt.figure(figsize=(10,6))

# ax1 = fig.add_subplot(511)
# ax1.plot(MMS2_denoised_B['date'],MMS2_denoised_B['Bx'], label='$B_x$')
# ax1.plot(MMS2_denoised_B['date'],MMS2_denoised_B['By'], label='$B_y$')
# ax1.plot(MMS2_denoised_B['date'],MMS2_denoised_B['Bz'], label='$B_z$')
# ax1.set_ylabel('B \n [nT]')
# ax1.set_ylim([-15,15])
# ax1.set_title('Cleaned Data')


# plt.legend()
# ax2 = fig.add_subplot(512)
# ax2.plot(MMS2_denoised_n['date'],MMS2_denoised_n['n'], label='$n$')
# ax2.set_ylabel('n \n [cm$^{-3}$]')
# #ax2.set_xticks([])
# #plt.grid('on')
# ax3 = fig.add_subplot(513)
# ax3.plot(MMS2_denoised_Tpara['date'],MMS2_denoised_Tpara['Tpara'], label='$T_{||}$')
# ax3.set_ylabel('$T_{||}$ \n [eV]')
# #ax3.set_xticks([])
# #plt.grid('on')
# ax4 = fig.add_subplot(514)
# ax4.plot(MMS2_denoised_Tperp['date'],MMS2_denoised_Tperp['Tperp'], label='$T_{⊥}$')
# ax4.set_ylabel('$T_{⊥}$ \n [eV]')
# #ax4.set_xticks([])
# #plt.grid('on')
# ax5 = fig.add_subplot(515)
# ax5.plot(MMS2_denoised_V['date'],MMS2_denoised_V['Vx'], label='$V_x$')
# ax5.plot(MMS2_denoised_V['date'],MMS2_denoised_V['Vy'], label='$V_y$')
# ax5.plot(MMS2_denoised_V['date'],MMS2_denoised_V['Vz'], label='$V_z$')
# ax5.set_ylabel('$V}$ \n [km s$^{-1}$]')

# plt.subplots_adjust(hspace=0.0)

# plt.legend()
# #plt.grid('on')

# plt.show()

# %%
# fig = plt.figure(figsize=(10,6))

# ax1 = fig.add_subplot(511)
# ax1.plot(MMS2_B['date'],MMS2_B['Bx'], label='$B_x$')
# ax1.plot(MMS2_B['date'],MMS2_B['By'], label='$B_y$')
# ax1.plot(MMS2_B['date'],MMS2_B['Bz'], label='$B_z$')
# ax1.set_ylabel('B \n [nT]')
# ax1.set_ylim([-15,15])
# ax1.set_title('Raw Data')
# #ax1.set_xticks([])
# #plt.grid('on')
# plt.legend()
# ax2 = fig.add_subplot(512)
# ax2.plot(MMS2_n['date'],MMS2_n['n'], label='$n$')
# ax2.set_ylabel('n \n [cm$^{-3}$]')
# #ax2.set_xticks([])
# #plt.grid('on')
# ax3 = fig.add_subplot(513)
# ax3.plot(MMS2_Tpara['date'],MMS2_Tpara['Tpara'], label='$T_{||}$')
# ax3.set_ylabel('$T_{||}$ \n [eV]')
# #ax3.set_xticks([])
# #plt.grid('on')
# ax4 = fig.add_subplot(514)
# ax4.plot(MMS2_Tperp['date'],MMS2_Tperp['Tperp'], label='$T_{⊥}$')
# ax4.set_ylabel('$T_{⊥}$ \n [eV]')
# #ax4.set_xticks([])
# #plt.grid('on')
# ax5 = fig.add_subplot(515)
# ax5.plot(MMS2_V['date'],MMS2_V['Vx'], label='$V_x$')
# ax5.plot(MMS2_V['date'],MMS2_V['Vy'], label='$V_y$')
# ax5.plot(MMS2_V['date'],MMS2_V['Vz'], label='$V_z$')
# ax5.set_ylabel('$V}$ \n [km s$^{-1}$]')

# plt.subplots_adjust(hspace=0.0)

# plt.legend()
# #plt.grid('on')

# plt.show()

# %%
# find if there are any missing values

# %%
# # electron data has a higher cadence than ion data, so we have to downsample.



# #closest_idx_des_2020-06-17-20-00-00-2020-06-17-21-00-00.txt
# #closest_idx_des_2020-06-17-20-00-00-2020-06-17-21-00-00.txt
# # closest_idx_des_2020-06-17-22-00-00-2020-06-17-23-00-00.txt

# closest_indices_des = (np.loadtxt('/Users/chle4971/iCloud/LASP-MacL4326/MMS/MMS_data/closest_idx_des_2020-06-17-21-00-00-2020-06-17-22-00-00.txt'))



# print(closest_indices_des)
# print(len(closest_indices_des))

# closest_indices_des = np.array(closest_indices_des).astype(int)

# print(closest_indices_des)
# #closest_indices_des = int(closest_indices_des)
# import matplotlib.pyplot as plt
# # #e = 1.6022e-19 
# from scipy.constants import e
# #closest_indices_des1 = np.intc(closest_indices_des)






# t1 = trange[0]

# t2 = trange[1]



# times_dis, Vi = get_data('mms2_dis_bulkv_gse_brst')

# times_des, Ve = get_data('mms2_des_bulkv_gse_brst')

# # print(len(times_dis))

# # #t1 = '2020-06-17/21:00:00'





# # closest_indices_des = []
# # closest_times_des = []
# #print(times_dis)


# #print(datetimes)


# ''' Function to find the closest unix times in specified array. 
# Extremely slow need to implement something faster. '''
# def closest(arr, K):
#     return min(range(len(arr)), key = lambda i: abs(arr[i]-K))




# # for t in range(len(times_dis)):
# #     idx = closest(times_des, times_dis[t])
# #     closest_indices_des.append(idx)
#     #closest_times_des.append(datetime.datetime.fromtimestamp(times_des[idx_des]).strftime('%Y-%m-%d %H:%M:%S'))

# #np.savetxt('/Users/chle4971/OneDrive - LASP, University of Colorado/LASP-MacL4326/MMS/MMS_data/closest_idx_des_%s-%s.txt', t1,t2, int(closest_idx_des),delimiter=',')   

# # # # get electron (150 ms) data down to ion (30 ms) cadence


# times1, ni = get_data('mms2_dis_numberdensity_brst')


# times_b, ne = get_data('mms2_des_numberdensity_brst')



# # # print(closest_indices_des)


# #print(np.shape(Vi))
# Vix = Vi[:, 0]
# Viy = Vi[:, 1]
# Viz = Vi[:, 2]

# Vex = Ve[:, 0]
# Vey = Ve[:, 1]
# Vez = Ve[:, 2]
# # # # # # for each position timestamp, find the closest velocity/B-field timestamp, save that index
# # # # #
# # # # # print(int(closest_indices_des))


# # Find x,y,z components of the current, J
# Jx = ni*e*(Vix - Vex[closest_indices_des])
# Jy = ni*e*(Viy - Vey[closest_indices_des])
# Jz = ni*e*(Viz - Vez[closest_indices_des])





# # Save current
# J = np.stack((Jx, Jy,Jz), axis=1)
# J_mag = np.sqrt(Jx**2+Jy**2+Jz**2)

# #print(np.shape(J))

# store_data('J', data = {'x': times_dis, 'y': J})
# store_data('J_mag', data={'x': times_dis, 'y': J_mag})


# kernel_size = 10
# kernel = np.ones(kernel_size) / kernel_size
# data_convolved_10 = np.convolve(J_mag, kernel, mode='same')

# time_convolved_10 = np.convolve(times_dis, kernel, mode='same')

# store_data('J_mag_convolved', data={'x': times_dis, 'y': data_convolved_10})

# #tlimit(['2020-06-18/10:00:00','2020-06-18/02:00:00'])
# tplot(['mms2_fgm_b_gse_brst_l2_btot','J_mag','J_mag_convolved'])


# Audio(sound_file, autoplay=True)

# Audio(sound_file, autoplay=True)

# %%
# # Save closest indices to a text file so you don't have to run through the slow code above every time.


# t1 = trange[0]

# t2 = trange[1]

# t3 = t1.replace(":", "-")
# t4 = t3.replace("/", "-")

# t5 = t2.replace(":", "-")
# t6 = t5.replace("/", "-")

# #print(closest_indices_des)

# #np.savetxt('/Users/chle4971/OneDrive - LASP, University of Colorado/LASP-MacL4326/MMS/MMS_data/closest_idx_des_%s-%s.txt', t1,t2, int(closest_idx_des),delimiter=',')   

# filename = 'closest_idx_des_%s-%s.txt' %(t4,t6)
# #print(filename)
# save_path = '/Users/chle4971/iCloud/LASP-MacL4326/MMS/MMS_data/'
# complete_name = os.path.join(save_path,filename)
# np.savetxt(complete_name, closest_indices_des, delimiter = ',')

# %%
# #tplot_names()
# from pytplot import tplot, get_data, store_data, tlimit, options,tplot_names
# import pytplot
# store_data('Temp_brst', data=['mms2_dis_temppara_brst','mms2_dis_tempperp_brst'])
# #tlimit(['2020-06-17/20:00:00','2020-06-17/21:00:00'])
# # tplot(['mms2_dis_energyspectr_omni_brst','mms2_des_energyspectr_omni_brst','mms2_dis_numberdensity_brst',
# #       'Temp_brst','mms2_fgm_b_lmn_brst_l2_bvec','mms2_dis_bulkv_lmn_brst','mms2_dis_prestensor_gse_brst'])

# times_fgm, B = get_data('mms2_fgm_b_gse_brst_l2_bvec')

# Bx = 'Bx'
# By = 'By'
# Bz = 'Bz'
# B_tot ='B_tot'
# store_data(Bx, data={'x': times_fgm, 'y': B[:, 0]})
# store_data(By, data={'x': times_fgm, 'y': B[:, 1]})
# store_data(Bz, data={'x': times_fgm, 'y': B[:, 2]})
# #store_data(B_tot, data={'x': times_fgm, 'y': B[:, 3]})

# times_fpi, V = get_data('mms2_dis_bulkv_gse_brst')

# Vx = 'Vx'
# Vy = 'Vy'
# Vz = 'Vz'
# V_tot ='V_tot'
# store_data(Vx, data={'x': times_fpi, 'y': V[:, 0]})
# store_data(Vy, data={'x': times_fpi, 'y': V[:, 1]})
# store_data(Vz, data={'x': times_fpi, 'y': V[:, 2]})
# #store_data(V_tot, data={'x': times_fpi, 'y': V[:, 3]})


# #pytplot.timebar([1451107201,1451117200,1451119999],'sgx',color='m',thick=5)

# %%
# %matplotlib inline
# tlimit(['2020-06-18/00:13:00','2020-06-18/00:18:00'])


# pytplot.tplot_options('wsize', [5000,9000])
# pytplot.tplot_options('vertical_spacing',0)
# pytplot.tplot_options('axis_font_size',8)
# pytplot.tplot_options('title_size',8)
# pytplot.tplot_options('y_axis_zoom',True)
# pytplot.tplot_options('crosshair',True)
# pytplot.tplot_options('yaxis_width',20)
# options('mms2_dis_energyspectr_omni_brst', 'panel_size', .7)
# options('mms2_des_energyspectr_omni_brst', 'panel_size', .7)
# options('mms2_dis_numberdensity_brst', 'panel_size', .7)
# #options('show_all_axes',bool=False)
# options('Temp_brst', 'panel_size', .5)
# options('Bx', 'panel_size', .7)
# options('By', 'panel_size', .7)
# options('Bz', 'panel_size', .7)
# options('Vz', 'panel_size', .7)
# options('Vy', 'panel_size', .7)
# options('Vx', 'panel_size', .7)

# options('Vx', 'var_label', 'Vx')
# #options('J_mag_convolved', 'ytitle', 'J')
# options('mms2_dis_energyspectr_omni_brst', 'ytitle', 'DIS')
# options('mms2_des_energyspectr_omni_brst', 'ytitle', 'DES')
# options('Temp_brst', 'ytitle', 'T')
# options('mms2_dis_numberdensity_brst','ytitle','n')

# #pytplot.timebar(['2020-06-17/21:50:00'],'mms2_dis_energyspectr_omni_brst',color='m',thick=2)
# pytplot.timebar(0,'Bx',databar =True,color='r')
# pytplot.timebar(0,'By',databar =True,color='r')
# pytplot.timebar(0,'Bz',databar =True,color='r')
# pytplot.timebar(0,'Vx',databar =True,color='r')
# pytplot.timebar(0,'Vy',databar =True,color='r')
# pytplot.timebar(0,'Vz',databar =True,color='r')
# tplot(['mms2_dis_energyspectr_omni_brst','mms2_des_energyspectr_omni_brst',
#        'mms2_dis_numberdensity_brst','Temp_brst','Bx','Vx','By','Vy','Bz','Vz'])

# %%
# #print(closest_indices_des)

# # print(len(closest_indices_des))
# # print(closest_indices_des)

# closest_idx_des = np.round((closest_indices_des))


# print(closest_idx_des)
# closest_idx_des1 = np.unique(closest_idx_des)


# #print(closest_idx_des1)

# %%
# np.savetxt('/Users/chle4971/OneDrive - LASP, University of Colorado/LASP-MacL4326/MMS/MMS_data/closest_idx_des1.txt',int(closest_idx_des1),delimiter=',')

# %%
# tplot_names()

# %%
# # Trying to make the plots look prettier


# import matplotlib.pyplot as plt
# import pytplot
# store_data('mms2_des_Vy_gse_brst_downsampled', data={'x': times_dis, 'y': Vey[closest_indices_des]})
# store_data('mms2_dis_Vy_gse_brst', data={'x': times_dis, 'y': Viy})

# options(['mms2_des_Vy_gse_brst_downsampled'], 'color','k')
# options(['mms2_dis_Vy_gse_brst'], 'color','k')



# store_data("mms2_dis_des_y_vel", data = ["mms2_des_Vy_gse_brst_downsampled", "mms2_dis_Vy_gse_brst"])
# #store_data('mms2_dis_des_y_vel', ['mms2_des_Vy_gse_brst_downsampled','mms2_dis_Vy_gse_brst'])

# #options(['mms2_dis_des_y_vel'],'title','mms2_dis_des_y_vel')

# #tplot('mms2_des_Vy_gse_brst_downsampled', var_label = ['mms2_dis_Vy_gse_brst'])
# #fig = plt.plot(figsize=[9,5]) 
# pytplot.tplot_options('wsize', [2000,7000])
# options('mms2_dis_energyspectr_omni_brst', 'panel_size', .7)
# options('mms2_des_energyspectr_omni_brst', 'panel_size', .7)
# options('mms2_dis_numberdensity_brst', 'panel_size', .7)
# options('Temp_brst', 'panel_size', .5)
# options('mms2_fgm_b_gse_brst_l2', 'panel_size', .7)


# options('mms2_dis_bulkv_gse_brst', 'panel_size', .7)
# options('mms2_dis_prestensor_gse_brst', 'panel_size', .5)
# options('mms2_fgm_b_gse_brst_l2_btot', 'panel_size', .5)
# options('J_mag_convolved','panel_size', .5)
# #options('mms2_fgm_b_gse_brst_l2', 'panel_size', .5)

# tplot(['mms2_dis_energyspectr_omni_brst','mms2_des_energyspectr_omni_brst','mms2_dis_numberdensity_brst',
#       'Temp_brst','mms2_fgm_b_gse_brst_l2','mms2_dis_bulkv_gse_brst','mms2_dis_prestensor_gse_brst','J_mag_convolved'],vert_spacing=10,gui=True)

# #tplot(['mms2_fgm_b_gse_brst_l2_btot','J_mag_convolved','mms2_des_Vy_gse_brst_downsampled','mms2_dis_Vy_gse_brst','mms2_dis_des_y_vel'])

# %%
# # plot the whole trajectory and highlight the section we're looking at
# # KH instabilities occured from trange = ['2020-06-17/20:00:00','2020-06-18/03:20:00']

# # create a nicely formatted string date for plots
# date1 = Pt_short_timestamp[0].strftime("%Y-%m-%d %H:%M:%S")
# date2 = Pt_short_timestamp[-1].strftime("%Y-%m-%d %H:%M:%S")


# # create a nicely formatted string date for filenames
# date3 = Pt_short_timestamp[0].strftime("%Y-%m-%d-%H-%M-%S")
# date4 = Pt_short_timestamp[-1].strftime("%Y-%m-%d-%H-%M-%S")


# pd.to_datetime(MMS1_pos['Pt'],unit='s')
# # create a nicely formatted string date spanning entire time period
# date5 = pd.to_datetime(MMS1_pos['Pt'][0],unit='s')
# date6 = pd.to_datetime(MMS1_pos['Pt'][-1],unit='s')


# fig = plt.figure(figsize=[20,20])
# fig.suptitle(r'%s -%s'%(date5,date6))

# ax1 = fig.add_subplot(2, 2, 1)
# p1 = plt.scatter(MMS1_pos['Px']/R_E,MMS1_pos['Py']/R_E,s=2)
# plt.Circle(( 0 , 0 ), R_E )
# ax1.grid()
# ax1.set_title(r'$x,y$ positions (GSE)')
# ax1.set_xlabel('x [$R_e$]')
# ax1.set_ylabel('y [$R_e$]')
# p11 = plt.scatter(MMS1_pos['Px'][index_st_P:index_end_P]/R_E,MMS1_pos['Py'][index_st_P:index_end_P]/R_E)
# ax1.legend([p11],['%s -\n %s'%(date1,date2)])
# # ax1.set_xlim([0.0,-20])
# # ax1.set_ylim([0,-23])


# ax2 = fig.add_subplot(2, 2, 2)
# p2 = plt.scatter(MMS1_pos['Px']/R_E,MMS1_pos['Pz']/R_E,s=2)
# ax2.grid()
# ax2.set_title(r'$x,z$ positions (GSE)')
# ax2.set_xlabel('x [$R_e$]')
# ax2.set_ylabel('z [$R_e$]')
# p22 = plt.scatter(MMS1_pos['Px'][index_st_P:index_end_P]/R_E,MMS1_pos['Pz'][index_st_P:index_end_P]/R_E)
# plt.Circle(( 0 , 0 ), R_E )
# ax2.legend([p22],['%s -\n %s'%(date1,date2)])




# ax3 = fig.add_subplot(2, 2, 3)
# p3 = plt.scatter(MMS1_pos['Py']/R_E,MMS1_pos['Pz']/R_E,s=2)
# p4 = plt.scatter(MMS1_pos['Py'][index_st_P:index_end_P]/R_E,MMS1_pos['Pz'][index_st_P:index_end_P]/R_E)
# plt.Circle(( 0 , 0 ), R_E )
# ax3.grid()
# ax3.set_title(r'$y,z$ positions (GSE)')
# ax3.set_xlabel('y [$R_e$]')
# ax3.set_ylabel('z [$R_e$]')
# ax3.legend([p4],['%s -\n %s'%(date1,date2)])


# # if save_figs == True:
# #     fig.savefig('/Users/chle4971/OneDrive - LASP, University of Colorado/LASP-MacL4326/MMS/images/Orbit_plot_%s_%s' %(date3,date4))

# %%
# convert GSE coordinate system to LMN

# %%
# mms3 data for time period

MMS3_B = pd.DataFrame({"times": times_b_mms3, "Bx": data_b_mms3[:,0],
                       "By": data_b_mms3[:,1], "Bz": data_b_mms3[:,2],"Bmag": data_b_mms3[:,3]})

MMS3_ni = pd.DataFrame({"times": times_ni_mms3, "ni": data_ni_mms3})

MMS3_Tipara = pd.DataFrame({"times": times_Tipara_mms3, "Tipara": data_Tipara_mms3})

MMS3_Tiperp = pd.DataFrame({"times": times_Tiperp_mms3, "Tiperp": data_Tiperp_mms3})

MMS3_Vi = pd.DataFrame({"times": times_vi_mms3, "Vix": data_vi_mms3[:,0],
                       "Viy": data_vi_mms3[:,1], "Viz": data_vi_mms3[:,2]})




b_field_mms4 = 'mms4_fgm_b_gse_brst_l2'
times_b_mms4, data_b_mms4 = get_data(b_field_mms4)


ni_mms4 = 'mms4_dis_numberdensity_brst'
times_ni_mms4, data_ni_mms4 = get_data(ni_mms4)

Tipara_mms4 = 'mms4_dis_temppara_brst'
times_Tipara_mms4, data_Tipara_mms4 = get_data(Tipara_mms4)

Tiperp_mms4 = 'mms4_dis_tempperp_brst'
times_Tiperp_mms4, data_Tiperp_mms4 = get_data(Tiperp_mms4)

Vi_mms4 = 'mms4_dis_bulkv_gse_brst'
times_vi_mms4, data_vi_mms4 = get_data(Vi_mms4)



# mms4 data for time period

MMS4_B = pd.DataFrame({"times": times_b_mms4, "Bx": data_b_mms4[:,0],
                       "By": data_b_mms4[:,1], "Bz": data_b_mms4[:,2],"Bmag": data_b_mms4[:,3]})

MMS4_ni = pd.DataFrame({"times": times_ni_mms4, "ni": data_ni_mms4})

MMS4_Tipara = pd.DataFrame({"times": times_Tipara_mms4, "Tipara": data_Tipara_mms4})

MMS4_Tiperp = pd.DataFrame({"times": times_Tiperp_mms4, "Tiperp": data_Tiperp_mms4})

MMS4_Vi = pd.DataFrame({"times": times_vi_mms4, "Vix": data_vi_mms4[:,0],
                       "Viy": data_vi_mms4[:,1], "Viz": data_vi_mms4[:,2]})

#OMNI_B_GSE = pd.DataFrame({""})
#     OMNI_Bx_GSE = 'BX_GSE'
#     times_OMNI_Bx, data_OMNI_Bx = get_data(OMNI_Bx_GSE)

#     OMNI_By_GSE = 'BY_GSE'
#     times_OMNI_By, data_OMNI_By = get_data(OMNI_By_GSE)

#     OMNI_Bz_GSE = 'BZ_GSE'
#     times_OMNI_Bz, data_OMNI_Bz = get_data(OMNI_Bz_GSE)

#     OMNI_Vix_GSE = 'VX_GSE'
#     times_OMNI_Vix, data_OMNI_Vix = get_data(OMNI_Vix_GSE)

#     OMNI_Viy_GSE = 'VY_GSE'
#     times_OMNI_Viy, data_OMNI_Viy = get_data(OMNI_Viy_GSE)

#     OMNI_Viz_GSE = 'VZ_GSE'
#     times_OMNI_Viz, data_OMNI_Viz = get_data(OMNI_Viz_GSE)


#     OMNI_IMF = 'IMF'
#     times_OMNI_IMF, data_OMNI_IMF = get_data(OMNI_IMF)

#     OMNI_flow_speed = 'flow_speed'
#     times_flow_speed, data_flow_speed = get_data(OMNI_flow_speed)    


#     #OMNI_B = pd.DataFrame({"times": times_OMNI_Bx, "Bx": data_OMNI_Bx, "By": data_OMNI_By, "Bz": data_OMNI_Bz})

#     OMNI_IMF = pd.DataFrame({"times":times_OMNI_IMF,"IMF":data_OMNI_IMF})

#     OMNI_flow_speed = pd.DataFrame({"times":times_flow_speed,"flow_speed":data_flow_speed})

#     OMNI_IMF['date'] = pd.to_datetime(OMNI_IMF['times'],unit='s')
#     OMNI_flow_speed['date'] = pd.to_datetime(OMNI_flow_speed['times'],unit='s')


MMS1_B['date'] = pd.to_datetime(MMS1_B['times'],unit='s')
MMS1_ni['date'] = pd.to_datetime(MMS1_ni['times'],unit='s')
MMS1_Tipara['date'] = pd.to_datetime(MMS1_Tipara['times'],unit='s')
MMS1_Tiperp['date'] = pd.to_datetime(MMS1_Tiperp['times'],unit='s')
MMS1_Vi['date'] = pd.to_datetime(MMS1_Vi['times'],unit='s')


MMS2_B['date'] = pd.to_datetime(MMS2_B['times'],unit='s')
MMS2_ni['date'] = pd.to_datetime(MMS2_ni['times'],unit='s')
MMS2_Tipara['date'] = pd.to_datetime(MMS2_Tipara['times'],unit='s')
MMS2_Tiperp['date'] = pd.to_datetime(MMS2_Tiperp['times'],unit='s')
MMS2_Vi['date'] = pd.to_datetime(MMS2_Vi['times'],unit='s')


MMS3_B['date'] = pd.to_datetime(MMS3_B['times'],unit='s')
MMS3_ni['date'] = pd.to_datetime(MMS3_ni['times'],unit='s')
MMS3_Tipara['date'] = pd.to_datetime(MMS3_Tipara['times'],unit='s')
MMS3_Tiperp['date'] = pd.to_datetime(MMS3_Tiperp['times'],unit='s')
MMS3_Vi['date'] = pd.to_datetime(MMS3_Vi['times'],unit='s')

MMS4_B['date'] = pd.to_datetime(MMS4_B['times'],unit='s')
MMS4_ni['date'] = pd.to_datetime(MMS4_ni['times'],unit='s')
MMS4_Tipara['date'] = pd.to_datetime(MMS4_Tipara['times'],unit='s')
MMS4_Tiperp['date'] = pd.to_datetime(MMS4_Tiperp['times'],unit='s')
MMS4_Vi['date'] = pd.to_datetime(MMS4_Vi['times'],unit='s')





if create_csv == 'yes':
    MMS2_B.to_csv('MMS2_B.csv', index=False)  
    MMS2_ni.to_csv('MMS2_ni.csv', index=False)  
    MMS2_Tipara.to_csv('MMS2_Tipara.csv', index=False)  
    MMS2_Tiperp.to_csv('MMS2_Tiperp.csv', index=False)  
    MMS2_Vi.to_csv('MMS2_Vi.csv', index=False)  

    MMS1_B.to_csv('MMS1_B.csv', index=False)  
    MMS1_ni.to_csv('MMS1_ni.csv', index=False)  
    MMS1_Tipara.to_csv('MMS1_Tipara.csv', index=False)  
    MMS1_Tiperp.to_csv('MMS1_Tiperp.csv', index=False)  
    MMS1_Vi.to_csv('MMS1_Vi.csv', index=False)  

    MMS3_B.to_csv('MMS3_B.csv', index=False)  
    MMS3_ni.to_csv('MMS3_ni.csv', index=False)  
    MMS3_Tipara.to_csv('MMS3_Tipara.csv', index=False)  
    MMS3_Tiperp.to_csv('MMS3_Tiperp.csv', index=False)  
    MMS3_Vi.to_csv('MMS3_Vi.csv', index=False)  

    MMS4_B.to_csv('MMS4_B.csv', index=False)  
    MMS4_ni.to_csv('MMS4_ni.csv', index=False)  
    MMS4_Tipara.to_csv('MMS4_Tipara.csv', index=False)  
    MMS4_Tiperp.to_csv('MMS4_Tiperp.csv', index=False)  
    MMS4_Vi.to_csv('MMS4_Vi.csv', index=False)  

    # plot data
import pytplot
#pytplot.tplot_options('title','Raw data')
options('mms2_fgm_b_gse_brst_l2','ytitle','Magnetic Field')
options('mms2_fgm_b_gse_brst_l2','ysubtitle','[nT]')
options('mms2_dis_bulkv_gse_brst','ytitle','V')
options('mms2_dis_bulkv_gse_brst','ysubtitle','[km/s]')

options('mms2_dis_numberdensity_brst','ytitle','n')
options('mms2_dis_numberdensity_brst','ysubtitle','[$cm^{-3}$]')

options('mms2_dis_prestensor_gse_brst','ytitle','P')
options('mms2_dis_prestensor_gse_brst','ysubtitle','[nPa]')

#tlimit(['2020-06-17/20:30:00','2020-06-18/01:30:00'])


# OMNI data
# tplot(['BX_GSE', 'BY_GSE', 'BZ_GSE', 'flow_speed', 'Vix', 'Viy', 'Viz', 'SYM_H'])


ne_MMS1 = 'mms1_des_numberdensity_brst'
times_ne_MMS1, data_ne_MMS1 = get_data(ne_MMS1)

Tepara_MMS1 = 'mms1_des_temppara_brst'
times_Tepara_MMS1, data_Tepara_MMS1 = get_data(Tepara_MMS1)

Teperp_MMS1 = 'mms1_des_tempperp_brst'
times_Teperp_MMS1, data_Teperp_MMS1 = get_data(Teperp_MMS1)

Ve_MMS1 = 'mms1_des_bulkv_gse_brst'
times_ve_MMS1, data_ve_MMS1 = get_data(Ve_MMS1)


MMS1_ne = pd.DataFrame({"times": times_ne_MMS1, "ne": data_ne_MMS1})

MMS1_Tepara = pd.DataFrame({"times": times_Tepara_MMS1, "Tepara": data_Tepara_MMS1})

MMS1_Teperp = pd.DataFrame({"times": times_Teperp_MMS1, "Teperp": data_Teperp_MMS1})

MMS1_Ve = pd.DataFrame({"times": times_ve_MMS1, "Vex": data_ve_MMS1[:,0],
                       "Vey": data_ve_MMS1[:,1], "Vez": data_ve_MMS1[:,2]})


ne_mms2 = 'mms2_des_numberdensity_brst'
times_ne_mms2, data_ne_mms2 = get_data(ne_mms2)

Tepara_mms2 = 'mms2_des_temppara_brst'
times_Tepara_mms2, data_Tepara_mms2 = get_data(Tepara_mms2)

Teperp_mms2 = 'mms2_des_tempperp_brst'
times_Teperp_mms2, data_Teperp_mms2 = get_data(Teperp_mms2)

Ve_mms2 = 'mms2_des_bulkv_gse_brst'
times_ve_mms2, data_ve_mms2 = get_data(Ve_mms2)



MMS2_ne = pd.DataFrame({"times": times_ne_mms2, "ne": data_ne_mms2})

MMS2_Tepara = pd.DataFrame({"times": times_Tepara_mms2, "Tepara": data_Tepara_mms2})

MMS2_Teperp = pd.DataFrame({"times": times_Teperp_mms2, "Teperp": data_Teperp_mms2})

MMS2_Ve = pd.DataFrame({"times": times_ve_mms2, "Vex": data_ve_mms2[:,0],
                       "Vey": data_ve_mms2[:,1], "Vez": data_ve_mms2[:,2]})



ne_mms3 = 'mms3_des_numberdensity_brst'
times_ne_mms3, data_ne_mms3 = get_data(ne_mms3)

Tepara_mms3 = 'mms3_des_temppara_brst'
times_Tepara_mms3, data_Tepara_mms3 = get_data(Tepara_mms3)

Teperp_mms3 = 'mms3_des_tempperp_brst'
times_Teperp_mms3, data_Teperp_mms3 = get_data(Teperp_mms3)

Ve_mms3 = 'mms3_des_bulkv_gse_brst'
times_ve_mms3, data_ve_mms3 = get_data(Ve_mms3)



MMS3_ne = pd.DataFrame({"times": times_ne_mms3, "ne": data_ne_mms3})

MMS3_Tepara = pd.DataFrame({"times": times_Tepara_mms3, "Tepara": data_Tepara_mms3})

MMS3_Teperp = pd.DataFrame({"times": times_Teperp_mms3, "Teperp": data_Teperp_mms3})

MMS3_Ve = pd.DataFrame({"times": times_ve_mms3, "Vex": data_ve_mms3[:,0],
                       "Vey": data_ve_mms3[:,1], "Vez": data_ve_mms3[:,2]})



# ne_mms4 = 'mms4_des_numberdensity_brst'
# times_ne_mms4, data_ne_mms4 = get_data(ne_mms4)

# Tepara_mms4 = 'mms4_des_temppara_brst'
# times_Tepara_mms4, data_Tepara_mms4 = get_data(Tepara_mms4)

# Teperp_mms4 = 'mms4_des_tempperp_brst'
# times_Teperp_mms4, data_Teperp_mms4 = get_data(Teperp_mms4)

# Ve_mms4 = 'mms4_des_bulkv_gse_brst'
# times_ve_mms4, data_ve_mms4 = get_data(Ve_mms4)



# mms4_ne = pd.DataFrame({"times": times_ne_mms4, "ne": data_ne_mms4})

# mms4_Tepara = pd.DataFrame({"times": times_Tepara_mms4, "Tepara": data_Tepara_mms4})

# mms4_Teperp = pd.DataFrame({"times": times_Teperp_mms4, "Teperp": data_Teperp_mms4})

# mms4_Ve = pd.DataFrame({"times": times_ve_mms4, "Vex": data_ve_mms4[:,0],
#                          "Vey": data_ve_mms4[:,1], "Vez": data_ve_mms4[:,2]})

MMS1_ne['date'] = pd.to_datetime(MMS1_ne['times'],unit='s')
MMS1_Tepara['date'] = pd.to_datetime(MMS1_Tepara['times'],unit='s')
MMS1_Teperp['date'] = pd.to_datetime(MMS1_Teperp['times'],unit='s')
MMS1_Ve['date'] = pd.to_datetime(MMS1_Ve['times'],unit='s')


MMS2_ne['date'] = pd.to_datetime(MMS2_ne['times'],unit='s')
MMS2_Tepara['date'] = pd.to_datetime(MMS2_Tepara['times'],unit='s')
MMS2_Teperp['date'] = pd.to_datetime(MMS2_Teperp['times'],unit='s')
MMS2_Ve['date'] = pd.to_datetime(MMS2_Ve['times'],unit='s')


MMS3_ne['date'] = pd.to_datetime(MMS3_ne['times'],unit='s')
MMS3_Tepara['date'] = pd.to_datetime(MMS3_Tepara['times'],unit='s')
MMS3_Teperp['date'] = pd.to_datetime(MMS3_Teperp['times'],unit='s')
MMS3_Ve['date'] = pd.to_datetime(MMS3_Ve['times'],unit='s')

# MMS4_ne['date'] = pd.to_datetime(MMS4_ne['times'],unit='s')
# MMS4_Tepara['date'] = pd.to_datetime(MMS4_Tepara['times'],unit='s')
# MMS4_Teperp['date'] = pd.to_datetime(MMS4_Teperp['times'],unit='s')
# MMS4_Ve['date'] = pd.to_datetime(MMS4_Ve['times'],unit='s')





if create_csv == 'yes':
    MMS2_ne.to_csv('MMS2_ne.csv', index=False)  
    MMS2_Tepara.to_csv('MMS2_Tepara.csv', index=False)  
    MMS2_Teperp.to_csv('MMS2_Teperp.csv', index=False)  
    MMS2_Ve.to_csv('MMS2_Ve.csv', index=False)  

    MMS1_ne.to_csv('MMS1_ne.csv', index=False)  
    MMS1_Tepara.to_csv('MMS1_Tepara.csv', index=False)  
    MMS1_Teperp.to_csv('MMS1_Teperp.csv', index=False)  
    MMS1_Ve.to_csv('MMS1_Ve.csv', index=False)  

    MMS3_ne.to_csv('MMS3_ne.csv', index=False)  
    MMS3_Tepara.to_csv('MMS3_Tepara.csv', index=False)  
    MMS3_Teperp.to_csv('MMS3_Teperp.csv', index=False)  
    MMS3_Ve.to_csv('MMS3_Ve.csv', index=False)  

#     MMS4_ne.to_csv('MMS4_ne.csv', index=False)  
#     MMS4_Tepara.to_csv('MMS4_Tepara.csv', index=False)  
#     MMS4_Teperp.to_csv('MMS4_Teperp.csv', index=False)  
#     MMS4_Ve.to_csv('MMS4_Ve.csv', index=False)

# %%
tplot(['mms4_des_temppara_brst'])
# Out:
# 22-Jul-24 13:43:52: The name mms4_des_temppara_brst is currently not in pytplot
# 22-Jul-24 13:43:52: The name mms4_des_temppara_brst is currently not in pytplot
# 22-Jul-24 13:43:52: Variable not found: mms4_des_temppara_brst

# %%
probe=['4']
electroni_vars = fpi(probe=probe,datatype='des-moms', trange=trange, data_rate='brst',center_measurement=True)
    # Load all of the FPI data
# Out:
# 22-Jul-24 13:49:39: Searching for local files...
# 22-Jul-24 13:49:39: No matching CDF versions found.

# %%
# ne_mms4 = 'mms4_des_numberdensity_brst'
# times_ne_mms4, data_ne_mms4 = get_data(ne_mms4)

# Tepara_mms4 = 'mms4_des_temppara_brst'
# times_Tepara_mms4, data_Tepara_mms4 = get_data(Tepara_mms4)

# Teperp_mms4 = 'mms4_des_tempperp_brst'
# times_Teperp_mms4, data_Teperp_mms4 = get_data(Teperp_mms4)

# Ve_mms4 = 'mms4_des_bulkv_gse_brst'
# times_ve_mms4, data_ve_mms4 = get_data(Ve_mms4)



# mms4_ne = pd.DataFrame({"times": times_ne_mms4, "ne": data_ne_mms4})

# mms4_Tepara = pd.DataFrame({"times": times_Tepara_mms4, "Tepara": data_Tepara_mms4})

# mms4_Teperp = pd.DataFrame({"times": times_Teperp_mms4, "Teperp": data_Teperp_mms4})

# mms4_Ve = pd.DataFrame({"times": times_ve_mms4, "Vex": data_ve_mms4[:,0],
#                          "Vey": data_ve_mms4[:,1], "Vez": data_ve_mms4[:,2]})
